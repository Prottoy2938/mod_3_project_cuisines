# %%
import pandas as pd

# %%
df= pd.read_csv('all_recipe_data.csv')
df.head()
# Out:
#                                          Recipe_Name  \
# 0                                         Bunny chow
# 1                   Jollof rice with fried plantains
# 2                                        Jollof rice
# 3  Suya fillet burger with sweet potato cubes and...
# 4                          Jollof rice with chicken
#
#                                   Recipe_Ingredients  Cuisine
# 0  2 tbsp vegetable oil ½ tsp cumin seeds ½ tsp f...  african
# 1  1 tbsp olive or vegetable oil 2 large onions, ...  african
# 2  400ml/14fl oz passata 3 tbsp tomato purée 2 fr...  african
# 3  4g smoked paprika  2g cayenne pepper 6g ginger...  african
# 4  300g/10½oz basmati rice 1 tbsp vegetable oil 8...  african

# %%
df.describe()
# Out:
#        Recipe_Name                                 Recipe_Ingredients  \
# count         5714                                               5714
# unique         475                                                477
# top     Bunny chow  1 tsp cloves 1 tsp fennel seeds  1 tsp black m...
# freq            44                                                 22
#
#                            Cuisine
# count                         5714
# unique                          22
# top     turkish_and_middle_eastern
# freq                           477

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5714 entries, 0 to 5713
# Data columns (total 3 columns):
# Recipe_Name           5714 non-null object
# Recipe_Ingredients    5714 non-null object
# Cuisine               5714 non-null object
# dtypes: object(3)
# memory usage: 134.0+ KB

# %%
df.shape
# Out:
# (5714, 3)

# %%
df= df.drop_duplicates(subset=None, keep='first', inplace=False)

# %%
df.isna().sum()
# Out:
# Recipe_Name           0
# Recipe_Ingredients    0
# Cuisine               0
# dtype: int64

# %%
df.shape
# Out:
# (5714, 3)

# %%
df.isnull().sum()
# Out:
# Recipe_Name           0
# Recipe_Ingredients    0
# Cuisine               0
# dtype: int64

# %%
# african= df[df['Cuisine']== 'african'].shape[0]
# american= df[df['Cuisine']== 'american'].shape[0]
# british= df[df['Cuisine']== 'british'].shape[0]
# caribbean= df[df['Cuisine']== 'caribbean'].shape[0]
# chinese= df[df['Cuisine']== 'chinese'].shape[0]
# east_european= df[df['Cuisine']== 'east_european'].shape[0]
# french= df[df['Cuisine']== 'french'].shape[0]
# greek= df[df['Cuisine']== 'greek'].shape[0]
# indian= df[df['Cuisine']== 'indian'].shape[0]
# irish= df[df['Cuisine']== 'irish'].shape[0]
# italian=df[df['Cuisine']== 'italian'].shape[0]
# japanese= df[df['Cuisine']== 'japanese'].shape[0]
# korean= df[df['Cuisine']== 'korean'].shape[0]
# mexican= df[df['Cuisine']== 'mexican'].shape[0]
# nordic= df[df['Cuisine']== 'nordic'].shape[0]
# north_african= df[df['Cuisine']== 'north_african'].shape[0]
# pakistani= df[df['Cuisine']== 'pakistani'].shape[0]
# portuguese= df[df['Cuisine']== 'portuguese'].shape[0]
# south_american= df[df['Cuisine']== 'south_american'].shape[0]
# spanish= df[df['Cuisine']== 'spanish'].shape[0]
# thai_south_east_asian= df[df['Cuisine']== 'thai_and_south-east_asian'].shape[0]
# turkish_middle_easter= df[df['Cuisine']== 'turkish_and_middle_easter'].shape[0]

# %%
american.bit_length()
# Out:
# 6

# %%
# bar plot of the 3 classes
# plt.bar(10,EAP_len,3, label="EAP")
# plt.bar(15,HPL_len,3, label="HPL")
# plt.bar(20,MWS_len,3, label="MWS")
# plt.legend()
# plt.ylabel('Number of examples')
# plt.title('Propoertion of examples')
# plt.show()
# plt.bar(10, african, label='african')
# plt.bar(15, american, label='american')
# plt.bar(20, british, label= 'british')
# plt.bar(25, spanish, label='spanish')
# plt.legend()
# plt.ylabel('Numbers')
# plt.title('Total Cuisines')
# plt.show()

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
df[df['Cuisine']=='french']
# Out:
#                                            Recipe_Name  \
# 504                                         Bunny chow
# 505                   Jollof rice with fried plantains
# 506                                        Jollof rice
# 507  Suya fillet burger with sweet potato cubes and...
# 508                          Jollof rice with chicken
# 509                  Red-red stew with spiced plantain
# 510                                            Bobotie
# 511                              South-African bobotie
# 512                                         Bunny chow
# 513                                      Zoe’s jollof
# 514                                   Zanzibar chicken
# 515            Vegan chilli with peanut butter cabbage
# 516                               Marinated vegetables
# 517                      Chocolate mealie meal pudding
# 518                                          Goat stew
# 519                   Swahili chicken and papaya salad
# 520                        Cape Malay vegetarian curry
# 521                 Chicken bastilla with orange salad
# 522                 Lamb and apricot Cape Malay curry
# 523                             Goat and tomato bredie
# 524      Grilled pork chops with blatjang and radishes
# 525           Jollof Quorn pilau with salted cucumber
# 526         Beef, black-eyed bean and plantain hotpot
# 527  Senegalese couscous with beef and vegetable sauce
# 528                                          BBQ sauce
# 529                                            Waffles
# 530                                    Vanilla cupcake
# 531                                          Pecan pie
# 532                                         Cherry pie
# 533                                          Cornbread
# ..                                                 ...
# 642   Lemon and thyme pork schnitzel with potato salad
# 643  Pork meatloaf with soured cream (Faschierter R...
# 644                             Creamy paprika chicken
# 645                             Pork fillet stroganoff
# 646  Shashlik kebabs with sour cream dip and plum s...
# 647                              Really good rye bread
# 648                                           Arlettes
# 649                          James Martin's coq au vin
# 650                                Rum and honey babas
# 651                                          Baguettes
# 652                                          Macaroons
# 653                                         Madeleines
# 654                                       Cheese sauce
# 655                                         Coq au vin
# 656                           Mary Berry's coq au vin
# 657                 Coq au vin with crème fraîche mash
# 658                                         Marjolaine
# 659                                         Opera cake
# 660                            Traditional puff pastry
# 661                                         Religieuse
# 662                                  Apple tarte tatin
# 663                       Christmas chocolate Yule log
# 664                           How to make crème brûlée
# 665                               Fabulous fruit tarts
# 666                                        Fruit tarts
# 667              Pâte sucrée (sweet shortcrust pastry)
# 668                                        Ratatouille
# 669                                        Tarte tatin
# 670                                        Tartiflette
# 671                    Eggs in pots (oeufs en cocotte)
#
#                                     Recipe_Ingredients Cuisine
# 504  2 tbsp vegetable oil ½ tsp cumin seeds ½ tsp f...  french
# 505  1 tbsp olive or vegetable oil 2 large onions, ...  french
# 506  400ml/14fl oz passata 3 tbsp tomato purée 2 fr...  french
# 507  4g smoked paprika  2g cayenne pepper 6g ginger...  french
# 508  300g/10½oz basmati rice 1 tbsp vegetable oil 8...  french
# 509  2 tbsp ground ginger 1 tbsp ground cinnamon 1 ...  french
# 510  50ml/2fl oz olive oil 1 onion, chopped 2 garli...  french
# 511  butter, for greasing 400ml/14fl oz full-fat mi...  french
# 667  90g/3½oz butter, softened  65g/2½oz caster sug...  french
# 668  2 aubergines 4 small courgettes 2 red peppers ...  french
# 669  2kg/4½lbs dessert apples, about 12, peeled 3 t...  french
# 670  1kg/2lb 4oz Charlotte potatoes, peeled 250g/8o...  french
# 671  150g/5½oz crème fraîche salt and freshly groun...  french
#
# [168 rows x 3 columns]

# %%
df.duplicated('Recipe_Name')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8        True
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24       True
# 25       True
# 26       True
# 27       True
# 28       True
# 29       True
#         ...
# 5684     True
# 5685     True
# 5686     True
# 5687     True
# 5688     True
# 5689     True
# 5690    False
# 5691    False
# 5692    False
# 5693    False
# 5694    False
# 5695    False
# 5696    False
# 5697    False
# 5698    False
# 5699    False
# 5700    False
# 5701    False
# 5702    False
# 5703    False
# 5704    False
# 5705    False
# 5706    False
# 5707    False
# 5708    False
# 5709    False
# 5710    False
# 5711    False
# 5712    False
# 5713    False
# Length: 5714, dtype: bool

# %%
df= df.drop_duplicates(subset='Recipe_Name')

# %%
df
# Out:
#                                             Recipe_Name  \
# 0                                            Bunny chow
# 1                      Jollof rice with fried plantains
# 2                                           Jollof rice
# 3     Suya fillet burger with sweet potato cubes and...
# 4                             Jollof rice with chicken
# 5                     Red-red stew with spiced plantain
# 6                                               Bobotie
# 7                                 South-African bobotie
# 9                                         Zoe’s jollof
# 10                                     Zanzibar chicken
# 11              Vegan chilli with peanut butter cabbage
# 12                                 Marinated vegetables
# 13                        Chocolate mealie meal pudding
# 14                                            Goat stew
# 15                     Swahili chicken and papaya salad
# 16                          Cape Malay vegetarian curry
# 17                   Chicken bastilla with orange salad
# 18                   Lamb and apricot Cape Malay curry
# 19                               Goat and tomato bredie
# 20        Grilled pork chops with blatjang and radishes
# 21             Jollof Quorn pilau with salted cucumber
# 22           Beef, black-eyed bean and plantain hotpot
# 23    Senegalese couscous with beef and vegetable sauce
# 48                                            BBQ sauce
# 49                                              Waffles
# 50                                      Vanilla cupcake
# 51                                            Pecan pie
# 52                                           Cherry pie
# 53                                            Cornbread
# 54                                            Doughnuts
# ...                                                 ...
# 5231                                    Rainbow noodles
# 5232      South-East Asian vegetable and egg-fried rice
# 5233                                Thai steamed salmon
# 5234                               Vegan Thai red curry
# 5235                                  Singapore noodles
# 5236              Thai noodles with cinnamon and prawns
# 5690                                            Baklava
# 5691                                            Maneesh
# 5692                                           Fattoush
# 5693                  Pomegranate and parsley tabbouleh
# 5694                                          Tabbouleh
# 5695                                         Lamb doner
# 5696                                         Sucuk pide
# 5697                                Simple baba ganoush
# 5698                                       Baba ganoush
# 5699                                      Lemon hummus
# 5700                                       Lokanta stew
# 5701                                       Mussel pilav
# 5702                                       Turkish eggs
# 5703                             Chunky halloumi chips
# 5704               Lighter hummus with vegetable sticks
# 5705                                  Chicken schnitzel
# 5706                                    Vine-baked feta
# 5707              Greens with giant couscous and tahini
# 5708                    Lamb skewers with Turkish salad
# 5709                               Moroccan lamb tagine
# 5710                                         Fesenjoon
# 5711                         Beef and aubergine fatteh
# 5712                                 Bulgur wheat balls
# 5713  Maple and balsamic glazed lamb chops with cous...
# 5702  200g/7oz Greek-style plain yoghurt 1 garlic cl...
# 5703  2 x 250g/9oz blocks halloumi cheese, each cut ...
# 5704  400g tin chickpeas, drained 100g/3½oz fat-free...
# 5705  50g/1¾oz plain flour 1 tsp smoked paprika 1 ts...
# 5706  6–8 large vine leaves (vacuum packed or in bri...
# 5707  130ml/4fl oz hot vegetable stock 60g/2¼oz whol...
# 5708  740g/1lb 10oz lamb fillet, trimmed and cubed 1...
# 5709  1 tsp cayenne pepper 2 tsp ground black pepper...
# 5710  250g/9oz walnut halves 2 ice cubes 125ml/4½fl ...
# 5711  4 pitta breads, split open and cut into nacho-...
# 5712  200g/7oz bulgur wheat  2 medium free-range egg...
# 5713  large handful fresh thyme sprigs, leaves picke...
#
#                          Cuisine
# 0                        african
# 1                        african
# 2                        african
# 3                        african
# 4                        african
# 5                        african
# 6                        african
# 7                        african
# 9                        african
# 10                       african
# 11                       african
# 12                       african
# 13                       african
# 14                       african
# 15                       african
# 16                       african
# 17                       african
# 18                       african
# 19                       african
# 20                       african
# 21                       african
# 22                       african
# 23                       african
# 48                      american
# 49                      american
# 50                      american
# 51                      american
# 52                      american
# 53                      american
# 54                      american
# ...                          ...
# 5231   thai_and_south-east_asian
# 5232   thai_and_south-east_asian
# 5233   thai_and_south-east_asian
# 5234   thai_and_south-east_asian
# 5235   thai_and_south-east_asian
# 5236   thai_and_south-east_asian
# 5690  turkish_and_middle_eastern
# 5691  turkish_and_middle_eastern
# 5692  turkish_and_middle_eastern
# 5693  turkish_and_middle_eastern
# 5694  turkish_and_middle_eastern
# 5695  turkish_and_middle_eastern
# 5696  turkish_and_middle_eastern
# 5697  turkish_and_middle_eastern
# 5698  turkish_and_middle_eastern
# 5699  turkish_and_middle_eastern
# 5700  turkish_and_middle_eastern
# 5701  turkish_and_middle_eastern
# 5702  turkish_and_middle_eastern
# 5703  turkish_and_middle_eastern
# 5704  turkish_and_middle_eastern
# 5705  turkish_and_middle_eastern
# 5706  turkish_and_middle_eastern
# 5707  turkish_and_middle_eastern
# 5708  turkish_and_middle_eastern
# 5709  turkish_and_middle_eastern
# 5710  turkish_and_middle_eastern
# 5711  turkish_and_middle_eastern
# 5712  turkish_and_middle_eastern
# 5713  turkish_and_middle_eastern
#
# [475 rows x 3 columns]

# %%
df[df['Cuisine']=='french']
# Out:
#                                Recipe_Name  \
# 648                               Arlettes
# 649              James Martin's coq au vin
# 650                    Rum and honey babas
# 651                              Baguettes
# 652                              Macaroons
# 653                             Madeleines
# 654                           Cheese sauce
# 655                             Coq au vin
# 656               Mary Berry's coq au vin
# 657     Coq au vin with crème fraîche mash
# 658                             Marjolaine
# 659                             Opera cake
# 660                Traditional puff pastry
# 661                             Religieuse
# 662                      Apple tarte tatin
# 663           Christmas chocolate Yule log
# 664               How to make crème brûlée
# 665                   Fabulous fruit tarts
# 666                            Fruit tarts
# 667  Pâte sucrée (sweet shortcrust pastry)
# 668                            Ratatouille
# 669                            Tarte tatin
# 670                            Tartiflette
# 671        Eggs in pots (oeufs en cocotte)
#
#                                     Recipe_Ingredients Cuisine
# 648  60g/2¼oz strong white bread flour, plus extra ...  french
# 649  25g/1oz butter 150g/5½oz shallots, peeled but ...  french
# 650  115g/4oz unsalted butter, at room temperature,...  french
# 651  250g/9oz strong white flour, plus extra for du...  french
# 652  125g/4½oz icing sugar 125g/4½oz ground almonds...  french
# 653  2 free-range eggs 100g/3½oz caster sugar 100g/...  french
# 654  25g/1oz butter 25g/1oz plain flour 400–500ml/1...  french
# 655  1 bottle good-quality red wine (preferably Pin...  french
# 656  600ml/20fl oz red wine 1 tbsp olive oil 1 larg...  french
# 657  1.5kg/3¼lb chicken, jointed  150g/5oz diced ba...  french
# 658  125g/4½oz blanched almonds  125g/4½oz blanched...  french
# 659  100g/3½fl oz caster sugar  3 tbsp kirsch 3 fre...  french
# 660  225g/8oz strong white flour, plus extra for fl...  french
# 661  60g/2¼oz butter, cut into cubes 75g/2½oz plain...  french
# 662  320g/11oz plain flour 225g/8oz ice-cold butter...  french
# 663  vegetable oil, for greasing 150g/5½oz golden c...  french
# 664  450ml/16fl oz double cream 50ml/2 fl oz whole ...  french
# 665  350g/12oz plain flour pinch salt 125g/4½oz uns...  french
# 666  500g/1lb 2oz plain flour, plus extra for dusti...  french
# 667  90g/3½oz butter, softened  65g/2½oz caster sug...  french
# 668  2 aubergines 4 small courgettes 2 red peppers ...  french
# 669  2kg/4½lbs dessert apples, about 12, peeled 3 t...  french
# 670  1kg/2lb 4oz Charlotte potatoes, peeled 250g/8o...  french
# 671  150g/5½oz crème fraîche salt and freshly groun...  french

# %%
african= df[df['Cuisine']== 'african'].shape[0]
american= df[df['Cuisine']== 'american'].shape[0]
british= df[df['Cuisine']== 'british'].shape[0]
caribbean= df[df['Cuisine']== 'caribbean'].shape[0]
chinese= df[df['Cuisine']== 'chinese'].shape[0]
east_european= df[df['Cuisine']== 'east_european'].shape[0]
french= df[df['Cuisine']== 'french'].shape[0]
greek= df[df['Cuisine']== 'greek'].shape[0]
indian= df[df['Cuisine']== 'indian'].shape[0]
irish= df[df['Cuisine']== 'irish'].shape[0]
italian=df[df['Cuisine']== 'italian'].shape[0]
japanese= df[df['Cuisine']== 'japanese'].shape[0]
korean= df[df['Cuisine']== 'korean'].shape[0]
mexican= df[df['Cuisine']== 'mexican'].shape[0]
nordic= df[df['Cuisine']== 'nordic'].shape[0]
north_african= df[df['Cuisine']== 'north_african'].shape[0]
pakistani= df[df['Cuisine']== 'pakistani'].shape[0]
portuguese= df[df['Cuisine']== 'portuguese'].shape[0]
south_american= df[df['Cuisine']== 'south_american'].shape[0]
spanish= df[df['Cuisine']== 'spanish'].shape[0]
thai_south_east_asian= df[df['Cuisine']== 'thai_and_south-east_asian'].shape[0]
turkish_middle_easter= df[df['Cuisine']== 'turkish_and_middle_easter'].shape[0]

# %%
plt.hist(df['Cuisine'], bins=1)
# plt.legend()
plt.xticks(df['Cuisine'],rotation='vertical')
plt.ylabel('Cuisine Numbers')
plt.title('Total Cuisines')
plt.show()
