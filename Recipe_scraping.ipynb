# %%
import requests
from bs4 import BeautifulSoup

# %%
bunnychow = requests.get('https://www.bbc.com/food/recipes/bunny_chow_38916')
bunnychow_text = bunnychow.text
bunnychow_soup = BeautifulSoup(bunnychow_text)
bunnychow_ingredients_list = bunnychow_soup.findAll('li', {'class':"recipe-ingredients__list-item"})
ingredients = [ingredient.text for ingredient in bunnychow_ingredients_list]

# %%
bunnychow_title = bunnychow_soup.find('h1', {'class':'gel-trafalgar content-title__text'})
bunnychow_title.text
# Out:
# 'Bunny chow'

# %%
african_recipes = requests.get('https://www.bbc.com/food/cuisines/african')
african_recipes_text = african_recipes.text
african_recipes_soup = BeautifulSoup(african_recipes_text)

african_recipes_list = african_recipes_soup.findAll('a', {'class':"promo promo__istats promo__main_course"})
# <a class="promo promo__istats promo__main_course" href="/food/recipes/suya_fillet_burger_with_59824"><div class="gel-layout gel-layout--flush"><div class="promo__image-container gel-layout__item gel-1/1"><div class="responsive-image-container__16/9"><img src="https://ichef.bbci.co.uk/food/ic/food_16x9_320/recipes/suya_fillet_burger_with_59824_16x9.jpg" class="promo__image lazy-loaded" alt="" data-src="https://ichef.bbci.co.uk/food/ic/food_16x9_{width}/recipes/suya_fillet_burger_with_59824_16x9.jpg"></div></div><div class="gel-layout__item promo__text promo__text--bottom-padding gel-1/1"><div class="gel-wrap"><div class="gel-layout"><div class="gel-layout__item promo__title-container"><h3 class="promo__title gel-pica">Suya fillet burger with sweet potato cubes and watermelon salad</h3><span class="promo__subtitle gel-long-primer">by Tobi Akingbolagun</span><p class="promo__synopsis gel-long-primer"></p></div></div></div></div></div><span class="promo__type gel-minion">Main course</span></a>

african_recipes_list[0]
# Out:
# <a class="promo promo__istats promo__main_course" href="/food/recipes/bunny_chow_38916"><div class="gel-layout gel-layout--flush"><div class="promo__image-container gel-layout__item gel-1/1"><div class="responsive-image-container__16/9"><img alt="" class="promo__image" data-class="promo__image" data-src="https://ichef.bbci.co.uk/food/ic/food_16x9_{width}/recipes/bunny_chow_38916_16x9.jpg"/></div></div><div class="gel-layout__item promo__text promo__text--bottom-padding gel-1/1"><div class="gel-wrap"><div class="gel-layout"><div class="gel-layout__item promo__title-container"><h3 class="promo__title gel-pica">Bunny chow</h3><span class="promo__subtitle gel-long-primer">by Atul Kochhar</span><p class="promo__synopsis gel-long-primer"></p></div></div></div></div></div><span class="promo__type gel-minion">Main course</span></a>

# %%
british_recipes = requests.get('https://www.bbc.com/food/cuisines/british')
british_recipes_text = british_recipes.text
british_recipes_soup = BeautifulSoup(british_recipes_text)
british_recipes_list = british_recipes_soup.findAll('div', {'class':"gel-layout__item gel-1/2 gel-1/3@m gel-1/4@xl"})
british_recipes_list[0].findNext('a').get('href')
# <div class="gel-layout__item gel-1/2 gel-1/3@m gel-1/4@xl">
# <a class="promo promo__istats promo__cakes_and_baking" href="/food/recipes/scones_35420"><div class="gel-layout gel-layout--flush"><div class="promo__image-container gel-layout__item gel-1/1"><div class="responsive-image-container__16/9"><img src="https://ichef.bbci.co.uk/food/ic/food_16x9_320/recipes/scones_35420_16x9.jpg" class="promo__image lazy-loaded" alt="" data-src="https://ichef.bbci.co.uk/food/ic/food_16x9_{width}/recipes/scones_35420_16x9.jpg"></div></div><div class="gel-layout__item promo__text promo__text--bottom-padding gel-1/1"><div class="gel-wrap"><div class="gel-layout"><div class="gel-layout__item promo__title-container"><h3 class="promo__title gel-pica">Cherry scones</h3><span class="promo__subtitle gel-long-primer">by Sara Danesin Medio</span><p class="promo__synopsis gel-long-primer"></p></div></div></div></div></div><span class="promo__type gel-minion">Cakes and baking</span></a></div>
# Out:
# '/food/recipes/cawl_92334'

# %%
african_recipe_urls = []
for recipe in african_recipes_list:
    url = "https://www.bbc.com" + recipe.get('href')
    african_recipe_urls.append(url)

african_recipe_urls
# Out:
# ['https://www.bbc.com/food/recipes/bunny_chow_38916',
#  'https://www.bbc.com/food/recipes/jollof_rice_with_fried_79619',
#  'https://www.bbc.com/food/recipes/jollof_rice_with_fried_84889',
#  'https://www.bbc.com/food/recipes/suya_fillet_burger_with_59824',
#  'https://www.bbc.com/food/recipes/jollof_rice_with_chicken_74636',
#  'https://www.bbc.com/food/recipes/red-red_stew_with_spiced_28798',
#  'https://www.bbc.com/food/recipes/bobotie_83671',
#  'https://www.bbc.com/food/recipes/bobotie_95101',
#  'https://www.bbc.com/food/recipes/bunny_chow_17677',
#  'https://www.bbc.com/food/recipes/zoes_jollof_43216',
#  'https://www.bbc.com/food/recipes/zanzibarchicken_85461',
#  'https://www.bbc.com/food/recipes/manyatis_vegetable_35397',
#  'https://www.bbc.com/food/recipes/sadzagoatstewwithcab_89103',
#  'https://www.bbc.com/food/recipes/swahilichickenandpap_71266',
#  'https://www.bbc.com/food/recipes/cape_malay_vegetarian_58096',
#  'https://www.bbc.com/food/recipes/chicken_bastilla_with_27181',
#  'https://www.bbc.com/food/recipes/lamb_and_apricot_cape_72967',
#  'https://www.bbc.com/food/recipes/goat_and_tomato_bredie_87584',
#  'https://www.bbc.com/food/recipes/grilled_pork_chops_with_74983',
#  'https://www.bbc.com/food/recipes/jollof_quorn_pilau_with_33526',
#  'https://www.bbc.com/food/recipes/beef_black-eyed-bean_and_85011',
#  'https://www.bbc.com/food/recipes/senegalese_couscous_with_45637']

# %%
african_ingredients = []
for URL in african_recipe_urls:
    recipe = requests.get(URL)
    recipe_text = recipe.text
    recipe_soup = BeautifulSoup(recipe_text)
    ingredients_list = recipe_soup.findAll('li', {'class':"recipe-ingredients__list-item"})
    ingredients = [ingredient.text for ingredient in ingredients_list]
    african_ingredients.append(ingredients)
african_ingredients
# Out:
# [['2 tbsp vegetable oil',
#   '½ tsp cumin seeds',
#   '½ tsp fennel seeds',
#   '2.5cm/1in piece of cinnamon stick',
#   '2 green cardamom pods',
#   '1 star anise',
#   '1 bay leaf',
#   '1 onion, finely chopped',
#   '2 tbsp South African curry powder ',
#   '2 tomatoes, chopped',
#   '1kg/2lb 2oz boneless leg of lamb, cut into 1.5cm/½in dices',
#   '1 tbsp finely chopped fresh ginger',
#   '1 tbsp finely chopped garlic ',
#   '10-12 curry leaves',
#   '2 large potatoes, cut in cubes the same size as the meat',
#   'salt',
#   '2 tbsp finely chopped coriander leaves',
#   '2 tbsp lime juice',
#   '2 loaves of crusty white bread, unsliced, each cut across in half in the middle and most of the crumbs removed ',
#   'coriander cress or sprigs, to garnish'],
#  ['1 tbsp olive or vegetable oil',
#   '2 large onions, sliced',
#   '2 x 400g/14oz cans plum tomatoes',
#   '1 red pepper, diced',
#   '4 tbsp tomato purée',
#   '¼ tsp cayenne pepper or chilli powder',
#   '1 tsp curry powder',
#   '1 bay leaf',
#   'sprig fresh thyme',
#   '1 stock cube',
#   '225g/8oz long-grain or basmati rice',
#   'salt and freshly ground black pepper',
#   '2 plantains, cut into slices and deep fried',
#   'green leaf salad'],
#  ['400ml/14fl oz passata',
#   '3 tbsp tomato purée',
#   '2 fresh red Scotch bonnet chillies, seeds removed',
#   '2 onions, chopped',
#   '2 red peppers, seeds removed and roughly chopped',
#   '8 garlic cloves, peeled',
#   '3 tbsp fresh rosemary leaves',
#   '1 tbsp fresh thyme leaves',
#   '2 tsp ground coriander',
#   '1½ tsp sweet smoked paprika',
#   '50ml/2fl oz olive oil',
#   '150g/5½oz cherry tomatoes, halved',
#   '800ml/1½ pints chicken stock or vegetable stock',
#   '2 bay leaves',
#   '500g/1lb 2oz long-grain rice, rinsed ',
#   '2 tbsp sunflower oil',
#   '2 ripe plantains, peeled and thickly sliced',
#   'small handful of coriander leaves, roughly chopped',
#   'sea salt and freshly ground black pepper',
#   'green salad, to serve'],
#  ['4g smoked paprika ',
#   '2g cayenne pepper',
#   '6g ginger powder',
#   '4g garlic powder',
#   '1g ground black pepper',
#   '11g onion salt ',
#   '7g ground turmeric ',
#   '6g extra hot chilli powder',
#   '1g ground uda pods (also known as selim pepper)',
#   '1 large egg yolk',
#   '4 tsp suya spice (see above)',
#   '2 tsp fresh lemon juice',
#   '125ml/4fl oz rapeseed oil',
#   '1-2 tsp just-boiled water',
#   '75g/2½oz peeled and deseeded watermelon, cut into 1cm/½in cubes ',
#   '75g/2½oz cucumber, cut into 1cm/½in cubes',
#   '75g/2½oz feta cheese, cut into 1cm/½in cubes',
#   '1 tbsp finely chopped fresh curly leaf parsley',
#   'large pinch nigella seeds, toasted',
#   '200g/7oz purple sweet potato (see tip)',
#   '200g/7oz sweet potato',
#   'vegetable oil, for deep frying',
#   '1 medium red onion, cut into rings ',
#   '2 tbsp olive oil, for frying ',
#   '1 tsp golden caster sugar',
#   '2 x 125g/4½oz beef fillet steaks',
#   '½ tsp coarsely ground black pepper ',
#   '2 white ciabatta rolls, cut in half',
#   '2 tbsp ‘suyannaise’ (see above)',
#   '1 beef tomato, sliced into rounds',
#   '1 Little Gem lettuce, shredded',
#   '2 tsp suya spice, plus extra to taste',
#   '50g/1¾oz smoke-flavoured vintage cheddar cheese, grated'],
#  ['300g/10½oz basmati rice',
#   '1 tbsp vegetable oil',
#   '8 boneless, skinless chicken thighs, cut in half',
#   '1 onion, roughly chopped',
#   '3 garlic cloves, grated',
#   '5cm/2 in piece fresh root ginger, peeled and finely grated',
#   '1 red chilli, deseeded and finely chopped',
#   '1 tsp smoked paprika',
#   '2 tbsp tomato purèe',
#   '700ml/1¼ pint tomato passata',
#   '300ml/10fl oz chicken stock, from a cube',
#   '2 red peppers, deseeded and roughly chopped',
#   '2 tbsp roughly chopped fresh coriander',
#   'freshly ground black pepper'],
#  ['2 tbsp ground ginger',
#   '1 tbsp ground cinnamon',
#   '1 tbsp ground nutmeg',
#   '1 tbsp cayenne pepper',
#   '½ tbsp ground cloves',
#   '200g/7oz dried black-eyed beans or 1 x 400g tin black-eyed beans, drained and rinsed',
#   '75ml/2½fl oz vegetable oil',
#   '2 red onions, finely chopped',
#   '2.5cm/1in piece fresh root ginger, finely grated',
#   '½ tbsp dried chilli flakes',
#   '½ red scotch bonnet chilli, deseeded and diced',
#   '½ tsp curry powder',
#   '½ tbsp chilli powder',
#   '1 x 400g tin chopped tomatoes',
#   '4 plum tomatoes, roughly chopped',
#   '1 tbsp tomato purée ',
#   '1 tsp sea salt',
#   '½tsp ground black pepper',
#   'garri, for sprinkling ',
#   '1 heaped tbsp kelewele dry spice mix, from above',
#   '1 small red onion, grated',
#   '5cm/2in fresh root ginger, grated',
#   'pinch sea salt',
#   'vegetable oil, for deep-frying ',
#   '4-6 ripe plantains, peeled and cut into chips',
#   'handful roasted peanuts, crushed',
#   'handful micro coriander cress',
#   '1 red chilli, thinly sliced',
#   'handful nasturtium flowers and leaves'],
#  ['50ml/2fl oz olive oil',
#   '1 onion, chopped',
#   '2 garlic cloves, crushed',
#   '500g/1lb 2oz lamb mince',
#   '1 tbsp hot curry powder',
#   '1 lemon, juice and zest only ',
#   '2 tbsp mango chutney',
#   '75g/2½oz sultanas',
#   '75g/2½oz toasted almonds',
#   '1 slice white bread, soaked in milk for 1 minute then squeezed dry',
#   'salt and freshly ground black pepper',
#   '4 bay leaves',
#   '3 free-range eggs',
#   '150ml/5fl oz milk',
#   'rice, cooked according to packet instructions',
#   'chutneys of your choice ',
#   'yoghurt'],
#  ['butter, for greasing',
#   '400ml/14fl oz full-fat milk',
#   '50g/1¾oz fresh white breadcrumbs',
#   '4 large free-range eggs, beaten',
#   '1 tbsp olive oil',
#   '1kg/2lb 4oz lamb mince',
#   '2 onions, finely chopped',
#   '1 bay leaf',
#   '2 garlic cloves, crushed',
#   '2 tbsp madras curry paste',
#   '250ml/9fl oz lamb stock',
#   '2 tbsp Worcestershire sauce',
#   '2 tbsp mango chutney',
#   '50g/1¾oz raisins',
#   '50g/1¾oz dried apricots, chopped',
#   '1 tbsp cider vinegar'],
#  ['1 tbsp olive oil',
#   '1 onion, thinly sliced',
#   '2 garlic cloves, finely chopped',
#   '1 green chilli, finely chopped',
#   '1 thumb-sized piece fresh ginger root, peeled and finely chopped',
#   '15 fresh curry leaves',
#   '2 tsp ground cumin',
#   '1 tsp fennel seeds',
#   '2 tsp ground coriander',
#   '1 tsp ground turmeric',
#   '2 tsp black mustard seeds',
#   '1 tbsp tomato purée',
#   '3 plum tomatoes, finely chopped',
#   '100g/3½oz tamarind paste',
#   '20 raw king prawns, peeled and deveined ',
#   'salt and freshly ground black pepper ',
#   '2 small unsliced whole white bread loaves, cut in half and hollowed out',
#   '2 tbsp toasted coconut flakes',
#   '2 tbsp fried curry leaves',
#   '2 tbsp fresh coriander cress',
#   '2 tbsp fresh basil cress'],
#  ['8 bone-in chicken thighs or drumsticks',
#   '1 large onion, roughly chopped',
#   '1 Scotch bonnet chilli, de-seeded, finely chopped',
#   '1 tbsp fresh or dried thyme leaves',
#   '2 tbsp crayfish powder (available from online specialists)',
#   '6 Guinea peppers (also known as grains of paradise), crushed',
#   '6 large tomatoes, roughly chopped',
#   '200g/7oz tomato purée',
#   '1 tsp salt',
#   '4 tbsp peanut oil or sunflower oil ',
#   '1 large onion, finely chopped',
#   '2 garlic cloves, crushed',
#   '1 tsp ground hot chilli powder',
#   '300g/10½oz long-grain white rice, washed and drained',
#   'handful chopped fresh parsley and coriander, to garnish '],
#  ['2 tbsp groundnut oil',
#   '1 large chicken, jointed into 8 pieces, skin on',
#   '2 onions, finely chopped',
#   '3 garlic cloves, crushed ',
#   '2 green chillies, chopped',
#   '3 green or red tomatoes, finely chopped',
#   '½ tsp ground turmeric',
#   '½ tsp cumin seeds',
#   '½ tsp coriander seeds',
#   '4 green cardamom pods',
#   '2 limes, juice only',
#   '275ml/½ pint chicken stock',
#   '2 x 400ml/14fl oz cans coconut milk',
#   '1 bunch basil',
#   'cooked basmati rice, to serve'],
#  ['3 tbsp olive oil',
#   '1 small onion, chopped',
#   '2 carrots, diced',
#   '½ red pepper, seeds removed and chopped',
#   '½ yellow pepper, seeds removed and chopped',
#   '½ green pepper, seeds removed and chopped',
#   '100g/3½oz green beans, chopped',
#   '2 tomatoes, chopped',
#   '3–4 chillies, seeds removed and flesh chopped',
#   'salt and freshly ground black pepper',
#   '375g/13oz white cornmeal (mealie meal)',
#   '½ small cabbage (or any seasonally vegetable), shredded',
#   '1 small onion, chopped',
#   '1 tomato, chopped',
#   '4 tbsp peanut butter'],
#  ['1kg/2lb 5½oz goat meat cut into 2.5cm/1in pieces',
#   'salt and freshly ground black pepper ',
#   '3 tbsp vegetable oil',
#   '25g/1oz butter',
#   '1 large onion, finely chopped',
#   '2 garlic cloves, chopped',
#   '4 carrots, finely chopped',
#   '2 tsp tomato purée',
#   '¼ tsp cloves',
#   '¼ tsp ginger powder',
#   'pinch cayenne pepper',
#   '2 tbsp lemon juice',
#   '450ml/15fl oz lamb or beef stock',
#   '2-3 sprigs fresh thyme',
#   '1 bay leaf ',
#   'salt and freshly ground black pepper',
#   '1 medium cabbage, shredded',
#   'salt',
#   '3-4 tbsp (or to taste) peanut butter',
#   '200g/7oz millet, cooked according to packet instructions'],
#  ['4 chicken breasts, each cut into three long strips',
#   '1 tsp crushed black peppercorns',
#   'pinch of cayenne pepper',
#   '1 tsp ground cinnamon',
#   '1 tsp ground ginger',
#   '1 tsp chilli',
#   '1 tsp turmeric',
#   '1 tsp coriander seeds',
#   '1 tsp ground cumin',
#   '1 lime, juice only',
#   '2 tbsp olive oil',
#   '1 lemon grass stalk ',
#   '2.5cm/1in fresh ginger, chopped',
#   '2 large garlic cloves, crushed',
#   '2 shallots, finely chopped',
#   '2 red chillies, chopped',
#   '1 tsp garam masala',
#   '1 tsp ground turmeric',
#   '400ml/14fl oz coconut milk',
#   '1 tin of chopped tomatoes ',
#   '1 tbsp of coriander leaves',
#   '1 papaya, peeled and sliced lengthways',
#   '1 red onion, peeled and sliced',
#   '1 lime, juice only ',
#   'olive oil',
#   'dash of sweet chilli sauce.',
#   'rice to serve'],
#  ['1 tsp cloves',
#   '1 tsp fennel seeds ',
#   '1 tsp black mustard seeds',
#   '4 cardamom pods, seeds only',
#   '½ tsp black peppercorns ',
#   '1 tsp ground cumin',
#   '1 dried red chilli ',
#   '1 tsp coriander seeds',
#   '1 tbsp ground turmeric',
#   '1 cinnamon stick',
#   '1 tsp ground ginger',
#   '4 curry leaves',
#   'handful dried apricots',
#   '1 tbsp olive oil',
#   '1 red onion, roughly chopped',
#   '1 red pepper, seeds removed, roughly chopped',
#   '1 yellow pepper, seeds removed, roughly chopped',
#   '2 garlic cloves, finely chopped',
#   '1 small cauliflower, cut into bite-sized pieces ',
#   '400g tin chickpeas, drained and rinsed',
#   'handful green beans, roughly chopped',
#   '1 heaped tbsp peach chutney',
#   '2 tbsp roughly chopped parsley',
#   '320g/11oz long-grain rice, to serve',
#   '4 flatbreads, to serve'],
#  ['3 tbsp olive oil',
#   '4 large onions, sliced',
#   '700g/1lb 9oz boneless, skinless chicken thighs or breasts',
#   '20g/¾oz fresh coriander, finely chopped',
#   '3 garlic cloves, crushed',
#   '1 tsp ras el hanout',
#   '¼ tsp ground turmeric',
#   '¼ tsp ground ginger',
#   '1/8 tsp ground black pepper',
#   '150ml/5fl oz chicken stock',
#   '2 tbsp runny honey',
#   '2 tsp ground cinnamon, plus extra for dusting',
#   '100g/3½oz blanched almonds',
#   '100g/3½oz shelled unsalted pistachio nuts',
#   '2 tbsp caster sugar',
#   '50g/1¾oz unsalted butter',
#   '5 large free-range eggs ',
#   '325g/11½oz filo pastry sheets',
#   '3 lemons, finely grated zest only',
#   '1 free-range egg yolk',
#   'icing sugar, for dusting',
#   'salt',
#   '3 tbsp olive oil',
#   '1 tbsp dried thyme',
#   '1 tsp lemon juice',
#   '5 oranges, peeled and segmented',
#   '200g/7oz carrots, peeled and cut into thick ribbons',
#   '1 large cucumber, peeled and cut into thick ribbons',
#   '150g/5½oz black olives, pitted and chopped',
#   '85g/3oz walnuts, roughly chopped',
#   'sea salt flakes'],
#  ['1 shoulder of lamb (approximately 1kg/2lb 4oz), diced',
#   '1 tsp ground coriander',
#   '1 tsp ground cumin',
#   '1 tsp garam masala',
#   '2 tsp ground turmeric',
#   '1 tbsp tamarind paste',
#   '2 tsp dried chillies ',
#   '1 tsp fennel seeds',
#   '3 garlic cloves ',
#   '1 cinnamon stick',
#   '3 garlic cloves, finely grated',
#   '1 red chilli, finely chopped',
#   '1cm/½in piece fresh root ginger, finely grated',
#   '2 tbsp sunflower oil',
#   '2 onions, thinly sliced',
#   '2 tsp dried chilli flakes',
#   '1 tsp fennel seeds',
#   '3 garlic cloves',
#   '1cm/½in piece fresh root ginger, finely grated',
#   '2 tbsp tomato purée',
#   '400g tin chopped tomatoes',
#   'large handful dried apricots, roughly chopped',
#   '2 tbsp apricot chutney',
#   '100g/3½oz desiccated coconut',
#   'bunch fresh coriander, roughly chopped, to serve',
#   '50g/1¾oz fresh coconut, grated, to serve',
#   '500g/1lb 2oz dried couscous',
#   '1 small cucumber, diced',
#   '1 pomegranate, seeds only',
#   'bunch fresh basil, roughly chopped',
#   'bunch flatleaf parsley, roughly chopped',
#   'bunch fresh coriander, roughly chopped',
#   'handful dried apricots, roughly chopped ',
#   '4 spring onions, roughly chopped '],
#  ['12 peppercorns',
#   '2 cardamom pods',
#   '12 cloves',
#   '2 tbsp oil ',
#   '2 large onions, sliced',
#   '100g/3½oz piece cooking chorizo',
#   '140ml/4½fl oz chicken stock ',
#   '2 cinnamon sticks',
#   '2.5cm/1in root ginger, grated',
#   '1 green chilli, chopped',
#   "2 goats' leg steaks",
#   '680g/1½ lb new potatoes, halved lengthways',
#   '110g/4oz tomatoes, quartered ',
#   '2 tbsp chopped fresh parsley',
#   'sea salt and freshly ground black pepper'],
#  ['80g/3oz salt',
#   '1 tsp coriander seeds',
#   '1 tsp fennel seeds',
#   '2 star anise',
#   '1 tbsp roughly chopped stem ginger',
#   '250g/9oz pork chops, trimmed ',
#   '350g/12oz dried apricots',
#   '175g/6oz raisins',
#   '7g/¼oz black mustard seeds',
#   '7g/¼oz white mustard seeds',
#   '250g/9oz caster sugar',
#   '375ml/13fl oz cider vinegar',
#   '100g/3½oz ground almonds',
#   'handful dried apricots, finely chopped ',
#   '1 red chilli, finely chopped',
#   'handful fresh coriander leaves',
#   '½ mooli, thinly sliced',
#   '½ black radish, thinly sliced',
#   '10 breakfast radishes, thinly sliced',
#   'olive oil, for drizzling',
#   'salt and freshly ground black pepper ',
#   'watercress, to serve'],
#  ['30g/1oz ground ginger ',
#   '30g/1oz garlic granules',
#   '45g/1½oz chilli flakes ',
#   '20g/¾oz dried thyme ',
#   '20g/¾oz ground cinnamon ',
#   '15g/½oz ground nutmeg',
#   '20g/¾oz ground coriander ',
#   '1 tbsp salt ',
#   '1 tbsp ground black pepper ',
#   '500g/1lb 2oz basmati rice ',
#   '5 tbsp olive oil ',
#   '1 onion, diced ',
#   '2 tsp salt ',
#   '300g/10½oz Quorn pieces ',
#   '4 tbsp jollof spice mix (see above)',
#   '1 large cucumber, cut in half lengthways and thinly sliced on an angle ',
#   '1 red onion, thinly sliced ',
#   '20g/¾oz rock salt '],
#  ['350g/12oz dried black-eyed beans',
#   '900g/2lb sirloin steak, cut into 1cm/½ in cubes',
#   '225ml/8fl oz vegetable oil',
#   '100ml/3½fl oz red palm oil or vegetable oil',
#   '1 large white onion, chopped',
#   '4 garlic cloves, finely chopped',
#   '4cm/2in piece ginger, grated',
#   '1 tsp dried chilli flakes',
#   '2 x 400g tins chopped tomatoes',
#   '2 tbsp tomato purée',
#   '2 beef stock cubes',
#   '2 sprigs fresh thyme',
#   '1 Scotch bonnet chilli, chopped',
#   '3 ripe plantain, peeled and sliced',
#   'salt and freshly ground black pepper'],
#  ['150g/5½oz millet couscous',
#   '150g/5½oz corn couscous',
#   '200g/7oz fonio (or quinoa)',
#   '1 tbsp butter',
#   '2 tbsp vegetable oil\u2028',
#   '750g/1lb 10oz beef (topside), cut into chunks',
#   '100ml/3½fl oz tomato purée\u2028',
#   '100ml/3½fl oz tomato passata\u2028 ',
#   'salt and freshly ground black pepper to taste',
#   '250g/9oz onions, chopped',
#   '100g/3½oz carrots, chopped',
#   '100g/3½oz turnips, chopped',
#   '100g/3½oz sweet potatoes, chopped',
#   '½ leek, chopped',
#   '1 celery stick, chopped',
#   '1 garlic clove, crushed']]

# %%
african_recipe_names = []
for URL in african_recipe_urls:
    recipe = requests.get(URL)
    recipe_text = recipe.text
    recipe_soup = BeautifulSoup(recipe_text)
    recipe_name = recipe_soup.find('h1', {'class':'gel-trafalgar content-title__text'})
    african_recipe_names.append(recipe_name.text)

# %%
african_ingredients
# Out:
# [['2 tbsp vegetable oil',
#   '½ tsp cumin seeds',
#   '½ tsp fennel seeds',
#   '2.5cm/1in piece of cinnamon stick',
#   '2 green cardamom pods',
#   '1 star anise',
#   '1 bay leaf',
#   '1 onion, finely chopped',
#   '2 tbsp South African curry powder ',
#   '2 tomatoes, chopped',
#   '1kg/2lb 2oz boneless leg of lamb, cut into 1.5cm/½in dices',
#   '1 tbsp finely chopped fresh ginger',
#   '1 tbsp finely chopped garlic ',
#   '10-12 curry leaves',
#   '2 large potatoes, cut in cubes the same size as the meat',
#   'salt',
#   '2 tbsp finely chopped coriander leaves',
#   '2 tbsp lime juice',
#   '2 loaves of crusty white bread, unsliced, each cut across in half in the middle and most of the crumbs removed ',
#   'coriander cress or sprigs, to garnish'],
#  ['1 tbsp olive or vegetable oil',
#   '2 large onions, sliced',
#   '2 x 400g/14oz cans plum tomatoes',
#   '1 red pepper, diced',
#   '4 tbsp tomato purée',
#   '¼ tsp cayenne pepper or chilli powder',
#   '1 tsp curry powder',
#   '1 bay leaf',
#   'sprig fresh thyme',
#   '1 stock cube',
#   '225g/8oz long-grain or basmati rice',
#   'salt and freshly ground black pepper',
#   '2 plantains, cut into slices and deep fried',
#   'green leaf salad'],
#  ['400ml/14fl oz passata',
#   '3 tbsp tomato purée',
#   '2 fresh red Scotch bonnet chillies, seeds removed',
#   '2 onions, chopped',
#   '2 red peppers, seeds removed and roughly chopped',
#   '8 garlic cloves, peeled',
#   '3 tbsp fresh rosemary leaves',
#   '1 tbsp fresh thyme leaves',
#   '2 tsp ground coriander',
#   '1½ tsp sweet smoked paprika',
#   '50ml/2fl oz olive oil',
#   '150g/5½oz cherry tomatoes, halved',
#   '800ml/1½ pints chicken stock or vegetable stock',
#   '2 bay leaves',
#   '500g/1lb 2oz long-grain rice, rinsed ',
#   '2 tbsp sunflower oil',
#   '2 ripe plantains, peeled and thickly sliced',
#   'small handful of coriander leaves, roughly chopped',
#   'sea salt and freshly ground black pepper',
#   'green salad, to serve'],
#  ['4g smoked paprika ',
#   '2g cayenne pepper',
#   '6g ginger powder',
#   '4g garlic powder',
#   '1g ground black pepper',
#   '11g onion salt ',
#   '7g ground turmeric ',
#   '6g extra hot chilli powder',
#   '1g ground uda pods (also known as selim pepper)',
#   '1 large egg yolk',
#   '4 tsp suya spice (see above)',
#   '2 tsp fresh lemon juice',
#   '125ml/4fl oz rapeseed oil',
#   '1-2 tsp just-boiled water',
#   '75g/2½oz peeled and deseeded watermelon, cut into 1cm/½in cubes ',
#   '75g/2½oz cucumber, cut into 1cm/½in cubes',
#   '75g/2½oz feta cheese, cut into 1cm/½in cubes',
#   '1 tbsp finely chopped fresh curly leaf parsley',
#   'large pinch nigella seeds, toasted',
#   '200g/7oz purple sweet potato (see tip)',
#   '200g/7oz sweet potato',
#   'vegetable oil, for deep frying',
#   '1 medium red onion, cut into rings ',
#   '2 tbsp olive oil, for frying ',
#   '1 tsp golden caster sugar',
#   '2 x 125g/4½oz beef fillet steaks',
#   '½ tsp coarsely ground black pepper ',
#   '2 white ciabatta rolls, cut in half',
#   '2 tbsp ‘suyannaise’ (see above)',
#   '1 beef tomato, sliced into rounds',
#   '1 Little Gem lettuce, shredded',
#   '2 tsp suya spice, plus extra to taste',
#   '50g/1¾oz smoke-flavoured vintage cheddar cheese, grated'],
#  ['300g/10½oz basmati rice',
#   '1 tbsp vegetable oil',
#   '8 boneless, skinless chicken thighs, cut in half',
#   '1 onion, roughly chopped',
#   '3 garlic cloves, grated',
#   '5cm/2 in piece fresh root ginger, peeled and finely grated',
#   '1 red chilli, deseeded and finely chopped',
#   '1 tsp smoked paprika',
#   '2 tbsp tomato purèe',
#   '700ml/1¼ pint tomato passata',
#   '300ml/10fl oz chicken stock, from a cube',
#   '2 red peppers, deseeded and roughly chopped',
#   '2 tbsp roughly chopped fresh coriander',
#   'freshly ground black pepper'],
#  ['2 tbsp ground ginger',
#   '1 tbsp ground cinnamon',
#   '1 tbsp ground nutmeg',
#   '1 tbsp cayenne pepper',
#   '½ tbsp ground cloves',
#   '200g/7oz dried black-eyed beans or 1 x 400g tin black-eyed beans, drained and rinsed',
#   '75ml/2½fl oz vegetable oil',
#   '2 red onions, finely chopped',
#   '2.5cm/1in piece fresh root ginger, finely grated',
#   '½ tbsp dried chilli flakes',
#   '½ red scotch bonnet chilli, deseeded and diced',
#   '½ tsp curry powder',
#   '½ tbsp chilli powder',
#   '1 x 400g tin chopped tomatoes',
#   '4 plum tomatoes, roughly chopped',
#   '1 tbsp tomato purée ',
#   '1 tsp sea salt',
#   '½tsp ground black pepper',
#   'garri, for sprinkling ',
#   '1 heaped tbsp kelewele dry spice mix, from above',
#   '1 small red onion, grated',
#   '5cm/2in fresh root ginger, grated',
#   'pinch sea salt',
#   'vegetable oil, for deep-frying ',
#   '4-6 ripe plantains, peeled and cut into chips',
#   'handful roasted peanuts, crushed',
#   'handful micro coriander cress',
#   '1 red chilli, thinly sliced',
#   'handful nasturtium flowers and leaves'],
#  ['50ml/2fl oz olive oil',
#   '1 onion, chopped',
#   '2 garlic cloves, crushed',
#   '500g/1lb 2oz lamb mince',
#   '1 tbsp hot curry powder',
#   '1 lemon, juice and zest only ',
#   '2 tbsp mango chutney',
#   '75g/2½oz sultanas',
#   '75g/2½oz toasted almonds',
#   '1 slice white bread, soaked in milk for 1 minute then squeezed dry',
#   'salt and freshly ground black pepper',
#   '4 bay leaves',
#   '3 free-range eggs',
#   '150ml/5fl oz milk',
#   'rice, cooked according to packet instructions',
#   'chutneys of your choice ',
#   'yoghurt'],
#  ['butter, for greasing',
#   '400ml/14fl oz full-fat milk',
#   '50g/1¾oz fresh white breadcrumbs',
#   '4 large free-range eggs, beaten',
#   '1 tbsp olive oil',
#   '1kg/2lb 4oz lamb mince',
#   '2 onions, finely chopped',
#   '1 bay leaf',
#   '2 garlic cloves, crushed',
#   '2 tbsp madras curry paste',
#   '250ml/9fl oz lamb stock',
#   '2 tbsp Worcestershire sauce',
#   '2 tbsp mango chutney',
#   '50g/1¾oz raisins',
#   '50g/1¾oz dried apricots, chopped',
#   '1 tbsp cider vinegar'],
#  ['1 tbsp olive oil',
#   '1 onion, thinly sliced',
#   '2 garlic cloves, finely chopped',
#   '1 green chilli, finely chopped',
#   '1 thumb-sized piece fresh ginger root, peeled and finely chopped',
#   '15 fresh curry leaves',
#   '2 tsp ground cumin',
#   '1 tsp fennel seeds',
#   '2 tsp ground coriander',
#   '1 tsp ground turmeric',
#   '2 tsp black mustard seeds',
#   '1 tbsp tomato purée',
#   '3 plum tomatoes, finely chopped',
#   '100g/3½oz tamarind paste',
#   '20 raw king prawns, peeled and deveined ',
#   'salt and freshly ground black pepper ',
#   '2 small unsliced whole white bread loaves, cut in half and hollowed out',
#   '2 tbsp toasted coconut flakes',
#   '2 tbsp fried curry leaves',
#   '2 tbsp fresh coriander cress',
#   '2 tbsp fresh basil cress'],
#  ['8 bone-in chicken thighs or drumsticks',
#   '1 large onion, roughly chopped',
#   '1 Scotch bonnet chilli, de-seeded, finely chopped',
#   '1 tbsp fresh or dried thyme leaves',
#   '2 tbsp crayfish powder (available from online specialists)',
#   '6 Guinea peppers (also known as grains of paradise), crushed',
#   '6 large tomatoes, roughly chopped',
#   '200g/7oz tomato purée',
#   '1 tsp salt',
#   '4 tbsp peanut oil or sunflower oil ',
#   '1 large onion, finely chopped',
#   '2 garlic cloves, crushed',
#   '1 tsp ground hot chilli powder',
#   '300g/10½oz long-grain white rice, washed and drained',
#   'handful chopped fresh parsley and coriander, to garnish '],
#  ['2 tbsp groundnut oil',
#   '1 large chicken, jointed into 8 pieces, skin on',
#   '2 onions, finely chopped',
#   '3 garlic cloves, crushed ',
#   '2 green chillies, chopped',
#   '3 green or red tomatoes, finely chopped',
#   '½ tsp ground turmeric',
#   '½ tsp cumin seeds',
#   '½ tsp coriander seeds',
#   '4 green cardamom pods',
#   '2 limes, juice only',
#   '275ml/½ pint chicken stock',
#   '2 x 400ml/14fl oz cans coconut milk',
#   '1 bunch basil',
#   'cooked basmati rice, to serve'],
#  ['3 tbsp olive oil',
#   '1 small onion, chopped',
#   '2 carrots, diced',
#   '½ red pepper, seeds removed and chopped',
#   '½ yellow pepper, seeds removed and chopped',
#   '½ green pepper, seeds removed and chopped',
#   '100g/3½oz green beans, chopped',
#   '2 tomatoes, chopped',
#   '3–4 chillies, seeds removed and flesh chopped',
#   'salt and freshly ground black pepper',
#   '375g/13oz white cornmeal (mealie meal)',
#   '½ small cabbage (or any seasonally vegetable), shredded',
#   '1 small onion, chopped',
#   '1 tomato, chopped',
#   '4 tbsp peanut butter'],
#  ['1kg/2lb 5½oz goat meat cut into 2.5cm/1in pieces',
#   'salt and freshly ground black pepper ',
#   '3 tbsp vegetable oil',
#   '25g/1oz butter',
#   '1 large onion, finely chopped',
#   '2 garlic cloves, chopped',
#   '4 carrots, finely chopped',
#   '2 tsp tomato purée',
#   '¼ tsp cloves',
#   '¼ tsp ginger powder',
#   'pinch cayenne pepper',
#   '2 tbsp lemon juice',
#   '450ml/15fl oz lamb or beef stock',
#   '2-3 sprigs fresh thyme',
#   '1 bay leaf ',
#   'salt and freshly ground black pepper',
#   '1 medium cabbage, shredded',
#   'salt',
#   '3-4 tbsp (or to taste) peanut butter',
#   '200g/7oz millet, cooked according to packet instructions'],
#  ['4 chicken breasts, each cut into three long strips',
#   '1 tsp crushed black peppercorns',
#   'pinch of cayenne pepper',
#   '1 tsp ground cinnamon',
#   '1 tsp ground ginger',
#   '1 tsp chilli',
#   '1 tsp turmeric',
#   '1 tsp coriander seeds',
#   '1 tsp ground cumin',
#   '1 lime, juice only',
#   '2 tbsp olive oil',
#   '1 lemon grass stalk ',
#   '2.5cm/1in fresh ginger, chopped',
#   '2 large garlic cloves, crushed',
#   '2 shallots, finely chopped',
#   '2 red chillies, chopped',
#   '1 tsp garam masala',
#   '1 tsp ground turmeric',
#   '400ml/14fl oz coconut milk',
#   '1 tin of chopped tomatoes ',
#   '1 tbsp of coriander leaves',
#   '1 papaya, peeled and sliced lengthways',
#   '1 red onion, peeled and sliced',
#   '1 lime, juice only ',
#   'olive oil',
#   'dash of sweet chilli sauce.',
#   'rice to serve'],
#  ['1 tsp cloves',
#   '1 tsp fennel seeds ',
#   '1 tsp black mustard seeds',
#   '4 cardamom pods, seeds only',
#   '½ tsp black peppercorns ',
#   '1 tsp ground cumin',
#   '1 dried red chilli ',
#   '1 tsp coriander seeds',
#   '1 tbsp ground turmeric',
#   '1 cinnamon stick',
#   '1 tsp ground ginger',
#   '4 curry leaves',
#   'handful dried apricots',
#   '1 tbsp olive oil',
#   '1 red onion, roughly chopped',
#   '1 red pepper, seeds removed, roughly chopped',
#   '1 yellow pepper, seeds removed, roughly chopped',
#   '2 garlic cloves, finely chopped',
#   '1 small cauliflower, cut into bite-sized pieces ',
#   '400g tin chickpeas, drained and rinsed',
#   'handful green beans, roughly chopped',
#   '1 heaped tbsp peach chutney',
#   '2 tbsp roughly chopped parsley',
#   '320g/11oz long-grain rice, to serve',
#   '4 flatbreads, to serve'],
#  ['3 tbsp olive oil',
#   '4 large onions, sliced',
#   '700g/1lb 9oz boneless, skinless chicken thighs or breasts',
#   '20g/¾oz fresh coriander, finely chopped',
#   '3 garlic cloves, crushed',
#   '1 tsp ras el hanout',
#   '¼ tsp ground turmeric',
#   '¼ tsp ground ginger',
#   '1/8 tsp ground black pepper',
#   '150ml/5fl oz chicken stock',
#   '2 tbsp runny honey',
#   '2 tsp ground cinnamon, plus extra for dusting',
#   '100g/3½oz blanched almonds',
#   '100g/3½oz shelled unsalted pistachio nuts',
#   '2 tbsp caster sugar',
#   '50g/1¾oz unsalted butter',
#   '5 large free-range eggs ',
#   '325g/11½oz filo pastry sheets',
#   '3 lemons, finely grated zest only',
#   '1 free-range egg yolk',
#   'icing sugar, for dusting',
#   'salt',
#   '3 tbsp olive oil',
#   '1 tbsp dried thyme',
#   '1 tsp lemon juice',
#   '5 oranges, peeled and segmented',
#   '200g/7oz carrots, peeled and cut into thick ribbons',
#   '1 large cucumber, peeled and cut into thick ribbons',
#   '150g/5½oz black olives, pitted and chopped',
#   '85g/3oz walnuts, roughly chopped',
#   'sea salt flakes'],
#  ['1 shoulder of lamb (approximately 1kg/2lb 4oz), diced',
#   '1 tsp ground coriander',
#   '1 tsp ground cumin',
#   '1 tsp garam masala',
#   '2 tsp ground turmeric',
#   '1 tbsp tamarind paste',
#   '2 tsp dried chillies ',
#   '1 tsp fennel seeds',
#   '3 garlic cloves ',
#   '1 cinnamon stick',
#   '3 garlic cloves, finely grated',
#   '1 red chilli, finely chopped',
#   '1cm/½in piece fresh root ginger, finely grated',
#   '2 tbsp sunflower oil',
#   '2 onions, thinly sliced',
#   '2 tsp dried chilli flakes',
#   '1 tsp fennel seeds',
#   '3 garlic cloves',
#   '1cm/½in piece fresh root ginger, finely grated',
#   '2 tbsp tomato purée',
#   '400g tin chopped tomatoes',
#   'large handful dried apricots, roughly chopped',
#   '2 tbsp apricot chutney',
#   '100g/3½oz desiccated coconut',
#   'bunch fresh coriander, roughly chopped, to serve',
#   '50g/1¾oz fresh coconut, grated, to serve',
#   '500g/1lb 2oz dried couscous',
#   '1 small cucumber, diced',
#   '1 pomegranate, seeds only',
#   'bunch fresh basil, roughly chopped',
#   'bunch flatleaf parsley, roughly chopped',
#   'bunch fresh coriander, roughly chopped',
#   'handful dried apricots, roughly chopped ',
#   '4 spring onions, roughly chopped '],
#  ['12 peppercorns',
#   '2 cardamom pods',
#   '12 cloves',
#   '2 tbsp oil ',
#   '2 large onions, sliced',
#   '100g/3½oz piece cooking chorizo',
#   '140ml/4½fl oz chicken stock ',
#   '2 cinnamon sticks',
#   '2.5cm/1in root ginger, grated',
#   '1 green chilli, chopped',
#   "2 goats' leg steaks",
#   '680g/1½ lb new potatoes, halved lengthways',
#   '110g/4oz tomatoes, quartered ',
#   '2 tbsp chopped fresh parsley',
#   'sea salt and freshly ground black pepper'],
#  ['80g/3oz salt',
#   '1 tsp coriander seeds',
#   '1 tsp fennel seeds',
#   '2 star anise',
#   '1 tbsp roughly chopped stem ginger',
#   '250g/9oz pork chops, trimmed ',
#   '350g/12oz dried apricots',
#   '175g/6oz raisins',
#   '7g/¼oz black mustard seeds',
#   '7g/¼oz white mustard seeds',
#   '250g/9oz caster sugar',
#   '375ml/13fl oz cider vinegar',
#   '100g/3½oz ground almonds',
#   'handful dried apricots, finely chopped ',
#   '1 red chilli, finely chopped',
#   'handful fresh coriander leaves',
#   '½ mooli, thinly sliced',
#   '½ black radish, thinly sliced',
#   '10 breakfast radishes, thinly sliced',
#   'olive oil, for drizzling',
#   'salt and freshly ground black pepper ',
#   'watercress, to serve'],
#  ['30g/1oz ground ginger ',
#   '30g/1oz garlic granules',
#   '45g/1½oz chilli flakes ',
#   '20g/¾oz dried thyme ',
#   '20g/¾oz ground cinnamon ',
#   '15g/½oz ground nutmeg',
#   '20g/¾oz ground coriander ',
#   '1 tbsp salt ',
#   '1 tbsp ground black pepper ',
#   '500g/1lb 2oz basmati rice ',
#   '5 tbsp olive oil ',
#   '1 onion, diced ',
#   '2 tsp salt ',
#   '300g/10½oz Quorn pieces ',
#   '4 tbsp jollof spice mix (see above)',
#   '1 large cucumber, cut in half lengthways and thinly sliced on an angle ',
#   '1 red onion, thinly sliced ',
#   '20g/¾oz rock salt '],
#  ['350g/12oz dried black-eyed beans',
#   '900g/2lb sirloin steak, cut into 1cm/½ in cubes',
#   '225ml/8fl oz vegetable oil',
#   '100ml/3½fl oz red palm oil or vegetable oil',
#   '1 large white onion, chopped',
#   '4 garlic cloves, finely chopped',
#   '4cm/2in piece ginger, grated',
#   '1 tsp dried chilli flakes',
#   '2 x 400g tins chopped tomatoes',
#   '2 tbsp tomato purée',
#   '2 beef stock cubes',
#   '2 sprigs fresh thyme',
#   '1 Scotch bonnet chilli, chopped',
#   '3 ripe plantain, peeled and sliced',
#   'salt and freshly ground black pepper'],
#  ['150g/5½oz millet couscous',
#   '150g/5½oz corn couscous',
#   '200g/7oz fonio (or quinoa)',
#   '1 tbsp butter',
#   '2 tbsp vegetable oil\u2028',
#   '750g/1lb 10oz beef (topside), cut into chunks',
#   '100ml/3½fl oz tomato purée\u2028',
#   '100ml/3½fl oz tomato passata\u2028 ',
#   'salt and freshly ground black pepper to taste',
#   '250g/9oz onions, chopped',
#   '100g/3½oz carrots, chopped',
#   '100g/3½oz turnips, chopped',
#   '100g/3½oz sweet potatoes, chopped',
#   '½ leek, chopped',
#   '1 celery stick, chopped',
#   '1 garlic clove, crushed']]

# %%
recipe_and_ingredients = list(zip(african_recipe_names, african_ingredients))
recipe_and_ingredients
# Out:
# [('Bunny chow',
#   ['2 tbsp vegetable oil',
#    '½ tsp cumin seeds',
#    '½ tsp fennel seeds',
#    '2.5cm/1in piece of cinnamon stick',
#    '2 green cardamom pods',
#    '1 star anise',
#    '1 bay leaf',
#    '1 onion, finely chopped',
#    '2 tbsp South African curry powder ',
#    '2 tomatoes, chopped',
#    '1kg/2lb 2oz boneless leg of lamb, cut into 1.5cm/½in dices',
#    '1 tbsp finely chopped fresh ginger',
#    '1 tbsp finely chopped garlic ',
#    '10-12 curry leaves',
#    '2 large potatoes, cut in cubes the same size as the meat',
#    'salt',
#    '2 tbsp finely chopped coriander leaves',
#    '2 tbsp lime juice',
#    '2 loaves of crusty white bread, unsliced, each cut across in half in the middle and most of the crumbs removed ',
#    'coriander cress or sprigs, to garnish']),
#  ('Jollof rice with fried plantains',
#   ['1 tbsp olive or vegetable oil',
#    '2 large onions, sliced',
#    '2 x 400g/14oz cans plum tomatoes',
#    '1 red pepper, diced',
#    '4 tbsp tomato purée',
#    '¼ tsp cayenne pepper or chilli powder',
#    '1 tsp curry powder',
#    '1 bay leaf',
#    'sprig fresh thyme',
#    '1 stock cube',
#    '225g/8oz long-grain or basmati rice',
#    'salt and freshly ground black pepper',
#    '2 plantains, cut into slices and deep fried',
#    'green leaf salad']),
#  ('Jollof rice',
#   ['400ml/14fl oz passata',
#    '3 tbsp tomato purée',
#    '2 fresh red Scotch bonnet chillies, seeds removed',
#    '2 onions, chopped',
#    '2 red peppers, seeds removed and roughly chopped',
#    '8 garlic cloves, peeled',
#    '3 tbsp fresh rosemary leaves',
#    '1 tbsp fresh thyme leaves',
#    '2 tsp ground coriander',
#    '1½ tsp sweet smoked paprika',
#    '50ml/2fl oz olive oil',
#    '150g/5½oz cherry tomatoes, halved',
#    '800ml/1½ pints chicken stock or vegetable stock',
#    '2 bay leaves',
#    '500g/1lb 2oz long-grain rice, rinsed ',
#    '2 tbsp sunflower oil',
#    '2 ripe plantains, peeled and thickly sliced',
#    'small handful of coriander leaves, roughly chopped',
#    'sea salt and freshly ground black pepper',
#    'green salad, to serve']),
#  ('Suya fillet burger with sweet potato cubes and watermelon salad',
#   ['4g smoked paprika ',
#    '2g cayenne pepper',
#    '6g ginger powder',
#    '4g garlic powder',
#    '1g ground black pepper',
#    '11g onion salt ',
#    '7g ground turmeric ',
#    '6g extra hot chilli powder',
#    '1g ground uda pods (also known as selim pepper)',
#    '1 large egg yolk',
#    '4 tsp suya spice (see above)',
#    '2 tsp fresh lemon juice',
#    '125ml/4fl oz rapeseed oil',
#    '1-2 tsp just-boiled water',
#    '75g/2½oz peeled and deseeded watermelon, cut into 1cm/½in cubes ',
#    '75g/2½oz cucumber, cut into 1cm/½in cubes',
#    '75g/2½oz feta cheese, cut into 1cm/½in cubes',
#    '1 tbsp finely chopped fresh curly leaf parsley',
#    'large pinch nigella seeds, toasted',
#    '200g/7oz purple sweet potato (see tip)',
#    '200g/7oz sweet potato',
#    'vegetable oil, for deep frying',
#    '1 medium red onion, cut into rings ',
#    '2 tbsp olive oil, for frying ',
#    '1 tsp golden caster sugar',
#    '2 x 125g/4½oz beef fillet steaks',
#    '½ tsp coarsely ground black pepper ',
#    '2 white ciabatta rolls, cut in half',
#    '2 tbsp ‘suyannaise’ (see above)',
#    '1 beef tomato, sliced into rounds',
#    '1 Little Gem lettuce, shredded',
#    '2 tsp suya spice, plus extra to taste',
#    '50g/1¾oz smoke-flavoured vintage cheddar cheese, grated']),
#  ('Jollof rice with chicken ',
#   ['300g/10½oz basmati rice',
#    '1 tbsp vegetable oil',
#    '8 boneless, skinless chicken thighs, cut in half',
#    '1 onion, roughly chopped',
#    '3 garlic cloves, grated',
#    '5cm/2 in piece fresh root ginger, peeled and finely grated',
#    '1 red chilli, deseeded and finely chopped',
#    '1 tsp smoked paprika',
#    '2 tbsp tomato purèe',
#    '700ml/1¼ pint tomato passata',
#    '300ml/10fl oz chicken stock, from a cube',
#    '2 red peppers, deseeded and roughly chopped',
#    '2 tbsp roughly chopped fresh coriander',
#    'freshly ground black pepper']),
#  ('Red-red stew with spiced plantain',
#   ['2 tbsp ground ginger',
#    '1 tbsp ground cinnamon',
#    '1 tbsp ground nutmeg',
#    '1 tbsp cayenne pepper',
#    '½ tbsp ground cloves',
#    '200g/7oz dried black-eyed beans or 1 x 400g tin black-eyed beans, drained and rinsed',
#    '75ml/2½fl oz vegetable oil',
#    '2 red onions, finely chopped',
#    '2.5cm/1in piece fresh root ginger, finely grated',
#    '½ tbsp dried chilli flakes',
#    '½ red scotch bonnet chilli, deseeded and diced',
#    '½ tsp curry powder',
#    '½ tbsp chilli powder',
#    '1 x 400g tin chopped tomatoes',
#    '4 plum tomatoes, roughly chopped',
#    '1 tbsp tomato purée ',
#    '1 tsp sea salt',
#    '½tsp ground black pepper',
#    'garri, for sprinkling ',
#    '1 heaped tbsp kelewele dry spice mix, from above',
#    '1 small red onion, grated',
#    '5cm/2in fresh root ginger, grated',
#    'pinch sea salt',
#    'vegetable oil, for deep-frying ',
#    '4-6 ripe plantains, peeled and cut into chips',
#    'handful roasted peanuts, crushed',
#    'handful micro coriander cress',
#    '1 red chilli, thinly sliced',
#    'handful nasturtium flowers and leaves']),
#  ('Bobotie',
#   ['50ml/2fl oz olive oil',
#    '1 onion, chopped',
#    '2 garlic cloves, crushed',
#    '500g/1lb 2oz lamb mince',
#    '1 tbsp hot curry powder',
#    '1 lemon, juice and zest only ',
#    '2 tbsp mango chutney',
#    '75g/2½oz sultanas',
#    '75g/2½oz toasted almonds',
#    '1 slice white bread, soaked in milk for 1 minute then squeezed dry',
#    'salt and freshly ground black pepper',
#    '4 bay leaves',
#    '3 free-range eggs',
#    '150ml/5fl oz milk',
#    'rice, cooked according to packet instructions',
#    'chutneys of your choice ',
#    'yoghurt']),
#  ('South-African bobotie',
#   ['butter, for greasing',
#    '400ml/14fl oz full-fat milk',
#    '50g/1¾oz fresh white breadcrumbs',
#    '4 large free-range eggs, beaten',
#    '1 tbsp olive oil',
#    '1kg/2lb 4oz lamb mince',
#    '2 onions, finely chopped',
#    '1 bay leaf',
#    '2 garlic cloves, crushed',
#    '2 tbsp madras curry paste',
#    '250ml/9fl oz lamb stock',
#    '2 tbsp Worcestershire sauce',
#    '2 tbsp mango chutney',
#    '50g/1¾oz raisins',
#    '50g/1¾oz dried apricots, chopped',
#    '1 tbsp cider vinegar']),
#  ('Bunny chow',
#   ['1 tbsp olive oil',
#    '1 onion, thinly sliced',
#    '2 garlic cloves, finely chopped',
#    '1 green chilli, finely chopped',
#    '1 thumb-sized piece fresh ginger root, peeled and finely chopped',
#    '15 fresh curry leaves',
#    '2 tsp ground cumin',
#    '1 tsp fennel seeds',
#    '2 tsp ground coriander',
#    '1 tsp ground turmeric',
#    '2 tsp black mustard seeds',
#    '1 tbsp tomato purée',
#    '3 plum tomatoes, finely chopped',
#    '100g/3½oz tamarind paste',
#    '20 raw king prawns, peeled and deveined ',
#    'salt and freshly ground black pepper ',
#    '2 small unsliced whole white bread loaves, cut in half and hollowed out',
#    '2 tbsp toasted coconut flakes',
#    '2 tbsp fried curry leaves',
#    '2 tbsp fresh coriander cress',
#    '2 tbsp fresh basil cress']),
#  ('Zoe’s jollof ',
#   ['8 bone-in chicken thighs or drumsticks',
#    '1 large onion, roughly chopped',
#    '1 Scotch bonnet chilli, de-seeded, finely chopped',
#    '1 tbsp fresh or dried thyme leaves',
#    '2 tbsp crayfish powder (available from online specialists)',
#    '6 Guinea peppers (also known as grains of paradise), crushed',
#    '6 large tomatoes, roughly chopped',
#    '200g/7oz tomato purée',
#    '1 tsp salt',
#    '4 tbsp peanut oil or sunflower oil ',
#    '1 large onion, finely chopped',
#    '2 garlic cloves, crushed',
#    '1 tsp ground hot chilli powder',
#    '300g/10½oz long-grain white rice, washed and drained',
#    'handful chopped fresh parsley and coriander, to garnish ']),
#  ('Zanzibar chicken',
#   ['2 tbsp groundnut oil',
#    '1 large chicken, jointed into 8 pieces, skin on',
#    '2 onions, finely chopped',
#    '3 garlic cloves, crushed ',
#    '2 green chillies, chopped',
#    '3 green or red tomatoes, finely chopped',
#    '½ tsp ground turmeric',
#    '½ tsp cumin seeds',
#    '½ tsp coriander seeds',
#    '4 green cardamom pods',
#    '2 limes, juice only',
#    '275ml/½ pint chicken stock',
#    '2 x 400ml/14fl oz cans coconut milk',
#    '1 bunch basil',
#    'cooked basmati rice, to serve']),
#  ('Vegan chilli with peanut butter cabbage',
#   ['3 tbsp olive oil',
#    '1 small onion, chopped',
#    '2 carrots, diced',
#    '½ red pepper, seeds removed and chopped',
#    '½ yellow pepper, seeds removed and chopped',
#    '½ green pepper, seeds removed and chopped',
#    '100g/3½oz green beans, chopped',
#    '2 tomatoes, chopped',
#    '3–4 chillies, seeds removed and flesh chopped',
#    'salt and freshly ground black pepper',
#    '375g/13oz white cornmeal (mealie meal)',
#    '½ small cabbage (or any seasonally vegetable), shredded',
#    '1 small onion, chopped',
#    '1 tomato, chopped',
#    '4 tbsp peanut butter']),
#  ('Goat stew',
#   ['1kg/2lb 5½oz goat meat cut into 2.5cm/1in pieces',
#    'salt and freshly ground black pepper ',
#    '3 tbsp vegetable oil',
#    '25g/1oz butter',
#    '1 large onion, finely chopped',
#    '2 garlic cloves, chopped',
#    '4 carrots, finely chopped',
#    '2 tsp tomato purée',
#    '¼ tsp cloves',
#    '¼ tsp ginger powder',
#    'pinch cayenne pepper',
#    '2 tbsp lemon juice',
#    '450ml/15fl oz lamb or beef stock',
#    '2-3 sprigs fresh thyme',
#    '1 bay leaf ',
#    'salt and freshly ground black pepper',
#    '1 medium cabbage, shredded',
#    'salt',
#    '3-4 tbsp (or to taste) peanut butter',
#    '200g/7oz millet, cooked according to packet instructions']),
#  ('Swahili chicken and papaya salad',
#   ['4 chicken breasts, each cut into three long strips',
#    '1 tsp crushed black peppercorns',
#    'pinch of cayenne pepper',
#    '1 tsp ground cinnamon',
#    '1 tsp ground ginger',
#    '1 tsp chilli',
#    '1 tsp turmeric',
#    '1 tsp coriander seeds',
#    '1 tsp ground cumin',
#    '1 lime, juice only',
#    '2 tbsp olive oil',
#    '1 lemon grass stalk ',
#    '2.5cm/1in fresh ginger, chopped',
#    '2 large garlic cloves, crushed',
#    '2 shallots, finely chopped',
#    '2 red chillies, chopped',
#    '1 tsp garam masala',
#    '1 tsp ground turmeric',
#    '400ml/14fl oz coconut milk',
#    '1 tin of chopped tomatoes ',
#    '1 tbsp of coriander leaves',
#    '1 papaya, peeled and sliced lengthways',
#    '1 red onion, peeled and sliced',
#    '1 lime, juice only ',
#    'olive oil',
#    'dash of sweet chilli sauce.',
#    'rice to serve']),
#  ('Cape Malay vegetarian curry',
#   ['1 tsp cloves',
#    '1 tsp fennel seeds ',
#    '1 tsp black mustard seeds',
#    '4 cardamom pods, seeds only',
#    '½ tsp black peppercorns ',
#    '1 tsp ground cumin',
#    '1 dried red chilli ',
#    '1 tsp coriander seeds',
#    '1 tbsp ground turmeric',
#    '1 cinnamon stick',
#    '1 tsp ground ginger',
#    '4 curry leaves',
#    'handful dried apricots',
#    '1 tbsp olive oil',
#    '1 red onion, roughly chopped',
#    '1 red pepper, seeds removed, roughly chopped',
#    '1 yellow pepper, seeds removed, roughly chopped',
#    '2 garlic cloves, finely chopped',
#    '1 small cauliflower, cut into bite-sized pieces ',
#    '400g tin chickpeas, drained and rinsed',
#    'handful green beans, roughly chopped',
#    '1 heaped tbsp peach chutney',
#    '2 tbsp roughly chopped parsley',
#    '320g/11oz long-grain rice, to serve',
#    '4 flatbreads, to serve']),
#  ('Chicken bastilla with orange salad',
#   ['3 tbsp olive oil',
#    '4 large onions, sliced',
#    '700g/1lb 9oz boneless, skinless chicken thighs or breasts',
#    '20g/¾oz fresh coriander, finely chopped',
#    '3 garlic cloves, crushed',
#    '1 tsp ras el hanout',
#    '¼ tsp ground turmeric',
#    '¼ tsp ground ginger',
#    '1/8 tsp ground black pepper',
#    '150ml/5fl oz chicken stock',
#    '2 tbsp runny honey',
#    '2 tsp ground cinnamon, plus extra for dusting',
#    '100g/3½oz blanched almonds',
#    '100g/3½oz shelled unsalted pistachio nuts',
#    '2 tbsp caster sugar',
#    '50g/1¾oz unsalted butter',
#    '5 large free-range eggs ',
#    '325g/11½oz filo pastry sheets',
#    '3 lemons, finely grated zest only',
#    '1 free-range egg yolk',
#    'icing sugar, for dusting',
#    'salt',
#    '3 tbsp olive oil',
#    '1 tbsp dried thyme',
#    '1 tsp lemon juice',
#    '5 oranges, peeled and segmented',
#    '200g/7oz carrots, peeled and cut into thick ribbons',
#    '1 large cucumber, peeled and cut into thick ribbons',
#    '150g/5½oz black olives, pitted and chopped',
#    '85g/3oz walnuts, roughly chopped',
#    'sea salt flakes']),
#  ('Lamb and apricot Cape Malay curry ',
#   ['1 shoulder of lamb (approximately 1kg/2lb 4oz), diced',
#    '1 tsp ground coriander',
#    '1 tsp ground cumin',
#    '1 tsp garam masala',
#    '2 tsp ground turmeric',
#    '1 tbsp tamarind paste',
#    '2 tsp dried chillies ',
#    '1 tsp fennel seeds',
#    '3 garlic cloves ',
#    '1 cinnamon stick',
#    '3 garlic cloves, finely grated',
#    '1 red chilli, finely chopped',
#    '1cm/½in piece fresh root ginger, finely grated',
#    '2 tbsp sunflower oil',
#    '2 onions, thinly sliced',
#    '2 tsp dried chilli flakes',
#    '1 tsp fennel seeds',
#    '3 garlic cloves',
#    '1cm/½in piece fresh root ginger, finely grated',
#    '2 tbsp tomato purée',
#    '400g tin chopped tomatoes',
#    'large handful dried apricots, roughly chopped',
#    '2 tbsp apricot chutney',
#    '100g/3½oz desiccated coconut',
#    'bunch fresh coriander, roughly chopped, to serve',
#    '50g/1¾oz fresh coconut, grated, to serve',
#    '500g/1lb 2oz dried couscous',
#    '1 small cucumber, diced',
#    '1 pomegranate, seeds only',
#    'bunch fresh basil, roughly chopped',
#    'bunch flatleaf parsley, roughly chopped',
#    'bunch fresh coriander, roughly chopped',
#    'handful dried apricots, roughly chopped ',
#    '4 spring onions, roughly chopped ']),
#  ('Goat and tomato bredie',
#   ['12 peppercorns',
#    '2 cardamom pods',
#    '12 cloves',
#    '2 tbsp oil ',
#    '2 large onions, sliced',
#    '100g/3½oz piece cooking chorizo',
#    '140ml/4½fl oz chicken stock ',
#    '2 cinnamon sticks',
#    '2.5cm/1in root ginger, grated',
#    '1 green chilli, chopped',
#    "2 goats' leg steaks",
#    '680g/1½ lb new potatoes, halved lengthways',
#    '110g/4oz tomatoes, quartered ',
#    '2 tbsp chopped fresh parsley',
#    'sea salt and freshly ground black pepper']),
#  ('Grilled pork chops with blatjang and radishes',
#   ['80g/3oz salt',
#    '1 tsp coriander seeds',
#    '1 tsp fennel seeds',
#    '2 star anise',
#    '1 tbsp roughly chopped stem ginger',
#    '250g/9oz pork chops, trimmed ',
#    '350g/12oz dried apricots',
#    '175g/6oz raisins',
#    '7g/¼oz black mustard seeds',
#    '7g/¼oz white mustard seeds',
#    '250g/9oz caster sugar',
#    '375ml/13fl oz cider vinegar',
#    '100g/3½oz ground almonds',
#    'handful dried apricots, finely chopped ',
#    '1 red chilli, finely chopped',
#    'handful fresh coriander leaves',
#    '½ mooli, thinly sliced',
#    '½ black radish, thinly sliced',
#    '10 breakfast radishes, thinly sliced',
#    'olive oil, for drizzling',
#    'salt and freshly ground black pepper ',
#    'watercress, to serve']),
#  ('Jollof Quorn pilau with salted cucumber ',
#   ['30g/1oz ground ginger ',
#    '30g/1oz garlic granules',
#    '45g/1½oz chilli flakes ',
#    '20g/¾oz dried thyme ',
#    '20g/¾oz ground cinnamon ',
#    '15g/½oz ground nutmeg',
#    '20g/¾oz ground coriander ',
#    '1 tbsp salt ',
#    '1 tbsp ground black pepper ',
#    '500g/1lb 2oz basmati rice ',
#    '5 tbsp olive oil ',
#    '1 onion, diced ',
#    '2 tsp salt ',
#    '300g/10½oz Quorn pieces ',
#    '4 tbsp jollof spice mix (see above)',
#    '1 large cucumber, cut in half lengthways and thinly sliced on an angle ',
#    '1 red onion, thinly sliced ',
#    '20g/¾oz rock salt ']),
#  ('Beef, black-eyed bean and plantain hotpot ',
#   ['350g/12oz dried black-eyed beans',
#    '900g/2lb sirloin steak, cut into 1cm/½ in cubes',
#    '225ml/8fl oz vegetable oil',
#    '100ml/3½fl oz red palm oil or vegetable oil',
#    '1 large white onion, chopped',
#    '4 garlic cloves, finely chopped',
#    '4cm/2in piece ginger, grated',
#    '1 tsp dried chilli flakes',
#    '2 x 400g tins chopped tomatoes',
#    '2 tbsp tomato purée',
#    '2 beef stock cubes',
#    '2 sprigs fresh thyme',
#    '1 Scotch bonnet chilli, chopped',
#    '3 ripe plantain, peeled and sliced',
#    'salt and freshly ground black pepper']),
#  ('Senegalese couscous with beef and vegetable sauce',
#   ['150g/5½oz millet couscous',
#    '150g/5½oz corn couscous',
#    '200g/7oz fonio (or quinoa)',
#    '1 tbsp butter',
#    '2 tbsp vegetable oil\u2028',
#    '750g/1lb 10oz beef (topside), cut into chunks',
#    '100ml/3½fl oz tomato purée\u2028',
#    '100ml/3½fl oz tomato passata\u2028 ',
#    'salt and freshly ground black pepper to taste',
#    '250g/9oz onions, chopped',
#    '100g/3½oz carrots, chopped',
#    '100g/3½oz turnips, chopped',
#    '100g/3½oz sweet potatoes, chopped',
#    '½ leek, chopped',
#    '1 celery stick, chopped',
#    '1 garlic clove, crushed'])]

# %%
recipe_and_ingredient_paragraph = []
for recipe in recipe_and_ingredients:
    concat_recipe = ' '.join(recipe[1])
    recipe_name_ingredient = (recipe[0], concat_recipe)
    recipe_and_ingredient_paragraph.append(recipe_name_ingredient)

recipe_and_ingredient_paragraph
# Out:
# [('Bunny chow',
#   '2 tbsp vegetable oil ½ tsp cumin seeds ½ tsp fennel seeds 2.5cm/1in piece of cinnamon stick 2 green cardamom pods 1 star anise 1 bay leaf 1 onion, finely chopped 2 tbsp South African curry powder  2 tomatoes, chopped 1kg/2lb 2oz boneless leg of lamb, cut into 1.5cm/½in dices 1 tbsp finely chopped fresh ginger 1 tbsp finely chopped garlic  10-12 curry leaves 2 large potatoes, cut in cubes the same size as the meat salt 2 tbsp finely chopped coriander leaves 2 tbsp lime juice 2 loaves of crusty white bread, unsliced, each cut across in half in the middle and most of the crumbs removed  coriander cress or sprigs, to garnish'),
#  ('Jollof rice with fried plantains',
#   '1 tbsp olive or vegetable oil 2 large onions, sliced 2 x 400g/14oz cans plum tomatoes 1 red pepper, diced 4 tbsp tomato purée ¼ tsp cayenne pepper or chilli powder 1 tsp curry powder 1 bay leaf sprig fresh thyme 1 stock cube 225g/8oz long-grain or basmati rice salt and freshly ground black pepper 2 plantains, cut into slices and deep fried green leaf salad'),
#  ('Jollof rice',
#   '400ml/14fl oz passata 3 tbsp tomato purée 2 fresh red Scotch bonnet chillies, seeds removed 2 onions, chopped 2 red peppers, seeds removed and roughly chopped 8 garlic cloves, peeled 3 tbsp fresh rosemary leaves 1 tbsp fresh thyme leaves 2 tsp ground coriander 1½ tsp sweet smoked paprika 50ml/2fl oz olive oil 150g/5½oz cherry tomatoes, halved 800ml/1½ pints chicken stock or vegetable stock 2 bay leaves 500g/1lb 2oz long-grain rice, rinsed  2 tbsp sunflower oil 2 ripe plantains, peeled and thickly sliced small handful of coriander leaves, roughly chopped sea salt and freshly ground black pepper green salad, to serve'),
# %%
import pandas as pd
africa_recipe= pd.DataFrame(recipe_and_ingredient_paragraph[1:])
newcol= 'African'
africa_recipe= africa_recipe.assign(target=newcol)
africa_recipe= africa_recipe.rename(columns={0: 'Recipe_Name', 1: 'Recipe_Ingredients'})
africa_recipe
# Out:
#                                           Recipe_Name  \
# 0                    Jollof rice with fried plantains
# 1                                         Jollof rice
# 2   Suya fillet burger with sweet potato cubes and...
# 3                           Jollof rice with chicken
# 4                   Red-red stew with spiced plantain
# 5                                             Bobotie
# 6                               South-African bobotie
# 7                                          Bunny chow
# 8                                       Zoe’s jollof
# 9                                    Zanzibar chicken
# 10            Vegan chilli with peanut butter cabbage
# 11                                          Goat stew
# 12                   Swahili chicken and papaya salad
# 13                        Cape Malay vegetarian curry
# 14                 Chicken bastilla with orange salad
# 15                 Lamb and apricot Cape Malay curry
# 16                             Goat and tomato bredie
# 17      Grilled pork chops with blatjang and radishes
# 18           Jollof Quorn pilau with salted cucumber
# 19         Beef, black-eyed bean and plantain hotpot
# 20  Senegalese couscous with beef and vegetable sauce
#
#                                    Recipe_Ingredients   target
# 0   1 tbsp olive or vegetable oil 2 large onions, ...  African
# 1   400ml/14fl oz passata 3 tbsp tomato purée 2 fr...  African
# 2   4g smoked paprika  2g cayenne pepper 6g ginger...  African
# 3   300g/10½oz basmati rice 1 tbsp vegetable oil 8...  African
# 4   2 tbsp ground ginger 1 tbsp ground cinnamon 1 ...  African
# 5   50ml/2fl oz olive oil 1 onion, chopped 2 garli...  African
# 6   butter, for greasing 400ml/14fl oz full-fat mi...  African
# 7   1 tbsp olive oil 1 onion, thinly sliced 2 garl...  African
# 8   8 bone-in chicken thighs or drumsticks 1 large...  African
# 9   2 tbsp groundnut oil 1 large chicken, jointed ...  African
# 10  3 tbsp olive oil 1 small onion, chopped 2 carr...  African
# 11  1kg/2lb 5½oz goat meat cut into 2.5cm/1in piec...  African
# 12  4 chicken breasts, each cut into three long st...  African
# 13  1 tsp cloves 1 tsp fennel seeds  1 tsp black m...  African
# 14  3 tbsp olive oil 4 large onions, sliced 700g/1...  African
# 15  1 shoulder of lamb (approximately 1kg/2lb 4oz)...  African
# 16  12 peppercorns 2 cardamom pods 12 cloves 2 tbs...  African
# 17  80g/3oz salt 1 tsp coriander seeds 1 tsp fenne...  African
# 18  30g/1oz ground ginger  30g/1oz garlic granules...  African
# 19  350g/12oz dried black-eyed beans 900g/2lb sirl...  African
# 20  150g/5½oz millet couscous 150g/5½oz corn cousc...  African

# %%
cuisines = ['american', 'british', 'caribbean', 'chinese', 'east_european', 'french', 
            'greek', 'indian', 'irish', 'italian', 'japanese', 'korean', 'mexican', 'nordic', 
            'north african', 'pakistani', 'portuguese', 'south_american', 'spanish',
            'thai_and_south-east_asian', 'turkish_and_middle_eastern']
# Out:
# 21

# %%
cuisines_recipe_urls = []
name_ingredients_cuisine = []
for cuisine in cuisines:
    cuisine_recipes = requests.get(f'https://www.bbc.com/food/cuisines/{cuisine}')
    cuisine_recipes_text = cuisine_recipes.text
    cuisine_recipes_soup = BeautifulSoup(cuisine_recipes_text)
    cuisines_recipes_list = cuisine_recipes_soup.findAll('div', {'class':"gel-layout__item gel-1/2 gel-1/3@m gel-1/4@xl"})
    
    for recipe in cuisines_recipes_list:
        url = "https://www.bbc.com" + recipe.findNext('a').get('href')
        #gives us a list of all recipe URLs
        cuisines_recipe_urls.append(url)
        
    for URL in cuisines_recipe_urls:
        recipe = requests.get(URL)
        recipe_text = recipe.text
        recipe_soup = BeautifulSoup(recipe_text)
        recipe_name = recipe_soup.find('h1', {'class':'gel-trafalgar content-title__text'}).text

        ingredients_list = recipe_soup.findAll('li', {'class':"recipe-ingredients__list-item"})
        ingredients = ' '.join([ingredient.text for ingredient in ingredients_list])
        
        n_i_c = (recipe_name, ingredients, cuisine)
        name_ingredients_cuisine.append(n_i_c)
        

        
        
# print(name_ingredients_cuisine)[1]
        
#     df = pd.DataFrame(name_ingredients_cuisine)[1:]

# df
# import pandas as pd
# africa_recipe= pd.DataFrame(recipe_and_ingredient_paragraph[1:])
# newcol= 'African'
# africa_recipe= africa_recipe.assign(target=newcol)
# africa_recipe= africa_recipe.rename(columns={0: 'Recipe_Name', 1: 'Recipe_Ingredients'})
# africa_recipe
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-207-8119c7d9fc49> in <module>
#      13
#      14     for URL in cuisines_recipe_urls:
# ---> 15         recipe = requests.get(URL)
#      16         recipe_text = recipe.text
#      17         recipe_soup = BeautifulSoup(recipe_text)
#
# /anaconda3/lib/python3.6/site-packages/requests/api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# /anaconda3/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# /anaconda3/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# /anaconda3/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# /anaconda3/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             except TypeError:  # Python 3
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#     382                     # Remove the TypeError from the exception chain in Python 3;
#
# /anaconda3/lib/python3.6/http/client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# /anaconda3/lib/python3.6/http/client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# /anaconda3/lib/python3.6/http/client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# /anaconda3/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# /anaconda3/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     292     def recv_into(self, *args, **kwargs):
#     293         try:
# --> 294             return self.connection.recv_into(*args, **kwargs)
#     295         except OpenSSL.SSL.SysCallError as e:
#     296             if self.suppress_ragged_eofs and e.args == (-1, 'Unexpected EOF'):
#
# /anaconda3/lib/python3.6/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1811             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1812         else:
# -> 1813             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1814         self._raise_ssl_error(self._ssl, result)
#    1815
#
# KeyboardInterrupt:

# %%
cuisines_recipe_urls = []

for cuisine in cuisines:
    cuisine_recipes = requests.get(f'https://www.bbc.com/food/cuisines/{cuisine}')
    cuisine_recipes_text = cuisine_recipes.text
    cuisine_recipes_soup = BeautifulSoup(cuisine_recipes_text)
    cuisines_recipes_list = cuisine_recipes_soup.findAll('div', {'class':"gel-layout__item gel-1/2 gel-1/3@m gel-1/4@xl"})
    
    for recipe in cuisines_recipes_list:
        url = "https://www.bbc.com" + recipe.findNext('a').get('href')
        #gives us a list of all recipe URLs
        cuisines_recipe_urls.append(url)

# %%
cuisines_recipe_urls
# Out:
# ['https://www.bbc.com/food/recipes/bbqsauce_4973',
#  'https://www.bbc.com/food/recipes/waffles_82356',
#  'https://www.bbc.com/food/recipes/cupcakes_99366',
#  'https://www.bbc.com/food/recipes/pecanpie_86028',
#  'https://www.bbc.com/food/recipes/cherrypie_91973',
#  'https://www.bbc.com/food/recipes/cornbread_86386',
#  'https://www.bbc.com/food/recipes/doughnuts_89027',
#  'https://www.bbc.com/food/recipes/carrotcake_70048',
#  'https://www.bbc.com/food/recipes/keylimepie_93185',
#  'https://www.bbc.com/food/recipes/pumpkinpie_70659',
#  'https://www.bbc.com/food/recipes/bananabread_85720',
#  'https://www.bbc.com/food/recipes/caesarsalad_72154',
#  'https://www.bbc.com/food/recipes/eggsbenedict_9435',
#  'https://www.bbc.com/food/recipes/key_lime_pie_53484',
#  'https://www.bbc.com/food/recipes/halloumi_chips_93711',
#  'https://www.bbc.com/food/recipes/lighter_hummus_54148',
#  'https://www.bbc.com/food/recipes/israeli_chicken_76953',
#  'https://www.bbc.com/food/recipes/vine-baked_feta_26601',
#  'https://www.bbc.com/food/recipes/greens_with_giant_28962',
#  'https://www.bbc.com/food/recipes/lamb_skewers_with_26099',
#  'https://www.bbc.com/food/recipes/moroccanlambtagine_6696',
#  'https://www.bbc.com/food/recipes/yasmins_fesenjoon_91487',
#  'https://www.bbc.com/food/recipes/beef_and_aubergine_46108',
#  'https://www.bbc.com/food/recipes/bulgur_wheat_balls_57026',
#  'https://www.bbc.com/food/recipes/maple_and_balsamic_26200']

# %%
name_ingredients_cuisine = []
recipe_names = []
for URL in cuisines_recipe_urls:
    recipe = requests.get(URL)
    recipe_text = recipe.text
    recipe_soup = BeautifulSoup(recipe_text)
    if recipe_soup.find('h1', {'class':'gel-trafalgar content-title__text'}) is not None:
        recipe_name = recipe_soup.find('h1', {'class':'gel-trafalgar content-title__text'}).text
        recipe_names.append(recipe_name)
recipe_names
    
#     ingredients_list = recipe_soup.findAll('li', {'class':"recipe-ingredients__list-item"})
#     ingredients = ' '.join([ingredient.text for ingredient in ingredients_list])

#     n_i_c = (recipe_name, ingredients, cuisine)
#     name_ingredients_cuisine.append(n_i_c)
# Out:
# ['BBQ sauce',
#  'Waffles',
#  'Vanilla cupcake',
#  'Pecan pie',
#  'Cherry pie',
#  'Cornbread',
#  'Doughnuts',
#  'Carrot cake traybake',
#  'Key lime pie',
#  'Pumpkin pie',
#  'Banana bread',
#  'Caesar salad',
#  "Cheat's eggs Benedict",
#  'Key lime pie with ginger pastry',
#  'Mac & cheese',
#  'Popcorn bars',
#  'Avocado salad',
#  'Banana muffins',
#  'Buffalo wings',
#  'Chopped salad',
#  'Damson cobbler',
#  'Eggs Benedict',
#  'Healthy banana muffins',
#  'Chocolate bark',
#  'Cawl',
#  'Turkey gravy',
#  'Scones',
#  'Custard',
#  'Game pie',
#  'Cherry scones',
#  'Sloe gin',
#  'Bannock',
#  'Diggers',
#  'Eggnog',
#  'Crumpets',
#  'Easy Eton mess',
#  'Eton mess',
#  'Fish cakes',
#  'Kedgeree',
#  'Mincemeat',
#  'Tea loaf',
#  'Apple sauce',
#  'Black bun',
#  'Lighter cranachan',
#  'Scottish cranachan ',
#  'Classic cranachan',
#  'Lighter Eton mess',
#  'Flapjacks',
#  'Jerk chicken',
#  'Rice and peas',
#  'Creole aubergines',
#  'Jerk chicken and flatbreads',
#  'Caribbean goat curry ',
#  'Salt fish fritters',
#  'Sticky gingerbread cake',
#  'Ginger, pecan and rum chocolate brownies',
#  'Hot hot roots with fresh mango and coconut relish',
#  'Jerk pork with sweet potato mash',
#  'Lamb, pepper and pineapple kebabs with lime, chilli and coriander mayonnaise',
#  'Saltfish and ackee with fried dumplings',
#  'Jerk chicken thighs',
#  'Sticky jerk chicken wings',
#  'Sunny vegetable patties',
#  'Blackened salmon with salsa',
#  'Caribbean chicken and pumpkin curry',
#  'Jamaican jerk chicken',
#  'Jamaican rum truffles ',
#  'Caribbean toastie cups with avocado, mango and mint',
#  'Homestyle jerk chicken wings',
#  'Prawn, sweet potato and lime curry with chilli and black pepper roti bread',
#  'Lime syrup',
#  'Herby black beans',
#  'Chow mein',
#  'Crispy duck with apricot and plum sauce',
#  'Prawn balls',
#  'Egg-fried rice',
#  'Egg fried rice with tomatoes',
#  'Fragrant pork and aubergines',
#  'Chinese lemon chicken',
#  'Mu shu chicken',
#  'Steamed chilli soy tofu',
#  'Chilli chicken',
#  'Lighter egg fried rice ',
#  'Steamed mussels',
#  'Easy chicken chow mein',
#  'Pickled cucumber',
#  'Easy vegetable stir-fry',
#  'Special fried rice',
#  'Pork noodles with bean sauce',
#  'Beef in oyster sauce',
#  "'Lion head' meatballs",
#  'Sichuan orange beef',
#  "'Dragon prawn' noodles",
#  'Easy beef stir-fry',
#  'Chinese five-spice spare ribs',
#  'Hoisin salmon with broccoli and noodles ',
#  'Blinis',
#  'Povitica ',
#  'Bigos stew',
#  'Dobos torte',
#  'Latvian salad',
#  'Sweet pierogi',
#  'Beef stroganoff',
#  'Pierogi ',
#  'Vodka strawberry cheesecake',
#  'Sausage and chorizo goulash',
#  'Walnut-crusted pork chops with figs',
#  'Aubergine and walnut caviar',
#  'Beef stroganoff with matchstick potatoes',
#  'Beef stroganoff with sautéed potatoes',
#  'Braised red cabbage with apples',
#  'Chicken paprika',
#  'Classic chicken Kiev with spring vegetables',
#  'Estonian lamb shanks',
#  'Lemon and thyme pork schnitzel with potato salad',
#  'Pork meatloaf with soured cream (Faschierter Rahmbraten)',
#  'Creamy paprika chicken',
#  'Pork fillet stroganoff',
#  'Shashlik kebabs with sour cream dip and plum sauce',
#  'Really good rye bread',
#  'Arlettes',
#  "James Martin's coq au vin",
#  'Rum and honey babas',
#  'Baguettes',
#  'Macaroons',
#  'Madeleines',
#  'Cheese sauce',
#  'Coq au vin',
#  "Mary Berry's coq au vin ",
#  'Coq au vin with crème fraîche mash',
#  'Marjolaine',
#  'Opera cake',
#  'Traditional puff pastry',
#  'Religieuse',
#  'Apple tarte tatin',
#  'Christmas chocolate Yule log',
#  'How to make crème brûlée',
#  'Fabulous fruit tarts',
#  'Fruit tarts',
#  'Pâte sucrée (sweet shortcrust pastry)',
#  'Ratatouille',
#  'Tarte tatin',
#  'Tartiflette',
#  'Eggs in pots (oeufs en cocotte)',
#  'Moussaka',
#  'Greek-style moussaka',
#  'Souvlakia',
#  'Easy Greek salad',
#  'Greek salad',
#  'Old rag pie',
#  'Spinach and feta pie (Spanakopita)',
#  'Greek apricots',
#  'Flaounes',
#  'Red lentil and aubergine moussaka',
#  'Greek-style pasta salad',
#  'Halloumi saganaki',
#  'Pork souvlaki with oregano',
#  'Stuffed vegetables',
#  'Feta and greens filo triangles',
#  'Galaktoboureko with orange syrup',
#  'Kozani chicken with prunes, saffron and paprika',
#  'Meatballs in tomato sauce with cinnamon and cumin (Soutzoukakia)',
#  'Neck of lamb with lemon and thyme',
#  'Cherry tomato, marinated feta and basil skewers',
#  'Mediterranean lamb chops',
#  'Mediterranean-style lamb chops',
#  'Souvlakia with tzatziki',
#  'Spinach, feta and pine nut salad',
#  'Naan bread',
#  'Kheer',
#  'Nimki',
#  'Ghoogra',
#  'Black dal',
#  'Chapatis',
#  'Tarka dal',
#  'Lamb kebabs',
#  'Lemon rice',
#  'Fish curry',
#  'Quick fish curry',
#  'Goat curry',
#  'Gulab jamun',
#  'Lamb curry with khooba roti ',
#  'Mango lassi',
#  'Okra curry',
#  'Onion bhaji',
#  'Pilau rice',
#  'Samosa pie ',
#  'Garam masala',
#  'Rogan josh',
#  'Quick veggie korma',
#  'Vegan chickpea curry',
#  'Green chutney',
#  'Champ',
#  'Colcannon',
#  'Potato soup',
#  "Paul Hollywood's soda bread",
#  'Soda bread',
#  'Stout bread',
#  'The Ulster fry',
#  'Irish rarebit',
#  'Irish stew',
#  'Irish soda bread',
#  'Rhubarb pie',
#  'Boxty with crisp streaky bacon and maple syrup',
#  'Homemade Irish cream',
#  'Irish beef stew',
#  'Irish fish chowder with soda bread',
#  'Traditional Irish stew',
#  'Irish coffee',
#  'White Irish stew',
#  'Soda bread rolls ',
#  'Homemade pork sausages with colcannon and apple sauce',
#  'Irish cream bread and butter pudding with cream',
#  'Pea and spring onion champ',
#  'Potato and roast red pepper soup',
#  'Seared beef salad with cashel blue dressing',
#  'Ragù',
#  'How to make lasagne',
#  'How to make lasagne',
#  'Meatzza',
#  'Rib ragù',
#  'Ciabatta',
#  "Paul Hollywood's focaccia",
#  'Tiramisu',
#  'Easy panettone',
#  'Panettone',
#  'Porchetta',
#  'Minestrone',
#  'Panzanella',
#  'Perfect panzanella',
#  'Easy panzanella',
#  'Tiramisini',
#  'Spaghetti with garlic and chilli',
#  'Alpine pizza',
#  'Vegetarian chard and cheese dumplings (strozzapreti)',
#  'Tuscan fries',
#  'Artichoke pasta',
#  'Bolognese sauce',
#  'Crab linguine',
#  'La gran lasagna',
#  'Prawn tempura',
#  'Tonkatsu pork',
#  'Furikake fries ',
#  'Salmon yakitori',
#  'Spring miso soup',
#  'Teriyaki salmon',
#  'Chicken yakitori',
#  'Chashu pork ramen ',
#  'Miso chicken with walnuts and grapes',
#  'How to make chicken teriyaki',
#  'Miso aubergine with noodles',
#  'Grilled aubergines with miso',
#  'Teriyaki chicken with leek and pepper stir-fry',
#  'Miso ramen soup with buckwheat noodles',
#  'Sweet miso-marinated salmon with soba noodles',
#  'Japanese-style chilli prawn canapés',
#  'Quick and easy sushi maki (sushi rolls)',
#  'Simple miso, tofu and mushroom ramen',
#  'Tempura scallops and asparagus with ponzu dressing',
#  'Tofu sushi bowl',
#  'Asian-inspired cod with stir fry ',
#  'Cod in a pistachio and matcha crumb',
#  'Chicken noodle miso soup',
#  'Sushi',
#  'Korean-inspired turkey bowl',
#  'Korean grilled beef short ribs (galbi gui)',
#  'Korean fried chicken',
#  'Korean bulgogi chicken stir-fry',
#  'Kimchi ',
#  'Halibut with spicy kimchi',
#  'White radish salad (Sangchae)',
#  'Ribbon beef tartare (Yukhoe)',
#  'Fiery octopus (Ojingeo bokkeum)',
#  'Pork, beans and kimchi with ssamjang',
#  'Ultimate Korean fried chicken with pickled radish',
#  'Kale and kohlrabi kimchi with pulled pork',
#  'Vegetarian fajitas ',
#  'Raw salsa',
#  'Pork taco',
#  'Fish tacos',
#  'Chicken mole poblano',
#  'Hot chocolate',
#  'Vegan nachos',
#  'Baked burrito',
#  'Corn tortilla',
#  'Real guacamole',
#  'Breakfast burrito',
#  'Chilli con carne',
#  'Carne con chile',
#  'Tortilla towers',
#  'Chilli chocolate truffles (Trufas de chocolate y chile pasilla)',
#  'Tropical churros',
#  'Turkey enchiladas',
#  'Spiced slow-cooked mutton with Mexican chillies, puréed squash and sautéed chard',
#  'Homemade soft tacos with beef and black beans',
#  'Buñuelos with spiced guava syrup',
#  'Smoky chicken quesadillas',
#  'Marinated ribs with tomatillo salsa, guacamole and tortilla chips',
#  'Mexican steak burrito',
#  'Grilled vegetable wraps with salsa and guacamole',
#  'Prinsesstårta',
#  'Cinnamon buns',
#  'Rye crispbread',
#  'Finnish pancakes',
#  'Finnish split pea soup',
#  'Norwegian tuna pasta bake',
#  'Savoury pies with Jarlsberg cheese and ham (Norwegian pierogi)',
#  'Cardamom and lemon cookies',
#  "Jansson's frestelse (Jansson’s temptation)",
#  'Kroppkakor (Swedish dumplings)',
#  'St Lucia buns',
#  'Vegan cinnamon buns',
#  'Swedish Christmas Glögg',
#  'Herring with dill and mustard potato salad',
#  'Speculaas biscuits (traditional continental Christmas biscuits)',
#  'Swedish Lucia rolls',
#  'Swedish-style mini-meatballs',
#  'Codfish (klippfisk) soup',
#  'Icelandic breaded lamb chops with spiced red cabbage',
#  'Rye bread',
#  'Cod gratin',
#  'Swedish meatballs with cream sauce',
#  "The Hairy Bikers' trout almondine",
#  'Almond rice pudding and cherry compôte',
#  'Roti',
#  'Mung dal saag',
#  'Lamb masala',
#  'Seekh kebabs with mint sauce',
#  'Meatball curry',
#  'Vegetable pakoras',
#  'Extra special beef biryani ',
#  'Saag gosht (lamb and spinach curry) with chapatis',
#  'Spicy naan bread',
#  'Chicken and spinach balti',
#  'Crunchy palak paneer',
#  'Instant Punjabi-style pickle',
#  'Chana dal with tarka and tamarind ',
#  'Seekh kebabs and spicy chilli corn',
#  'Pakistani chicken pulao',
#  'How to make chapatis',
#  'Onion bhajis',
#  'Bhindi bhaji',
#  'Adhraki gosht (lamb masala in a tomato and ginger sauce)',
#  'Chicken korma with cashew nuts',
#  'Masala mutton shanks with lemon rice',
#  'Marinated roast leg of lamb (raan) served with seasoned yoghurt (tadka raita)',
#  'Seafood biryani with crunchy salad and masala raita',
#  'Si dal (black urid lentils)',
#  'Almond tart',
#  'Pork and clams',
#  'Easy Portuguese custard tarts ',
#  'Easy piri-piri chicken',
#  'Caldo verde (Portuguese cabbage soup)',
#  'Piri-piri prawns and harissa couscous',
#  'Portuguese custard tarts',
#  'Piri-piri roast chicken',
#  'Piri-piri prawns',
#  'Salt cod fritters',
#  'Fine egg custard flan',
#  'Caldeirada (Portuguese monster fish stew)',
#  'Portuguese coriander, garlic and sourdough soup ',
#  'Portuguese pork with clams',
#  'Superfood salad with a piri-piri dressing',
#  'Feijoada ',
#  'Chicken and chorizo empanadas',
#  'Barbecued sirloin with chimichurri sauce',
#  'Quinoa salad with mint and mango',
#  'Salmon ceviche with fennel salad',
#  'Spiced beef empanadas',
#  'Scallop stew',
#  'How to make beef empanadas',
#  'Classic mojito',
#  'Aji de gallina',
#  'Sea bass ceviche',
#  'Cassava and cheese fritters (Bolinhos de mandioca e queijo)',
#  'Ceviche of sea bass with lime and mango salsa',
#  'Prawns in chupe sauce with spicy mash',
#  'Vegetarian quinoa burger',
#  'Lomo saltado with chips',
#  'Peruvian-style suckling pig',
#  'Sea bass ceviche on corn husks with a palm heart salad',
#  'Paella',
#  'Tumbet',
#  'Spanish-style tortilla',
#  "The Hairy Bikers' paella ",
#  'Roast pork',
#  'Arroz verde',
#  'Fideuà ',
#  'Patatas bravas',
#  'Chorizo tapas',
#  'Flamenco eggs',
#  'Easy patatas bravas  ',
#  'Baked sea bream Rota-style',
#  'Catalan fish stew',
#  'Trout croquettes',
#  'Lunchbox chorizo frittata',
#  'Spanish tortilla ',
#  'Hake with chorizo and potatoes (Merluza à la Gallega)',
#  'Moorish meatballs',
#  'Basque chicken and chorizo pie',
#  'Baked Spanish risotto',
#  'Chicken and chorizo paella',
#  'Gazpacho Hispaniola',
#  'Pistachio and white chocolate churros',
#  'Broad beans with pata negra ham',
#  'Easy pad Thai',
#  "Nadiya's pad Thai",
#  'Pad Thai',
#  'Chicken pad Thai',
#  'Tom yum soup',
#  'Apple momos',
#  'Beef rendang with herby rice ',
#  'Slow cooker chicken pho',
#  'Beef rendang ',
#  'Thai green curry',
#  'Thai pork kebabs',
#  'Thai green curry paste',
#  'Thai fish curry ',
#  'Tofu mee goreng noodles ',
#  'Bang bang turkey',
#  'Chilli pork with pineapple rice',
#  'Coconut fish curry',
#  'Golden egg curry',
#  'Rainbow noodles',
#  'South-East Asian vegetable and egg-fried rice',
#  'Thai steamed salmon',
#  'Vegan Thai red curry',
#  'Singapore noodles',
#  'Thai noodles with cinnamon and prawns',
#  'Baklava',
#  'Maneesh',
#  'Fattoush',
#  'Pomegranate and parsley tabbouleh',
#  'Tabbouleh',
#  'Lamb doner',
#  'Sucuk pide',
#  'Simple baba ganoush',
#  'Baba ganoush',
#  'Lemon hummus ',
#  'Lokanta stew',
#  'Mussel pilav',
#  'Turkish eggs',
#  'Chunky halloumi chips ',
#  'Lighter hummus with vegetable sticks',
#  'Chicken schnitzel',
#  'Vine-baked feta',
#  'Greens with giant couscous and tahini',
#  'Lamb skewers with Turkish salad',
#  'Moroccan lamb tagine',
#  'Fesenjoon ',
#  'Beef and aubergine fatteh ',
#  'Bulgur wheat balls',
#  'Maple and balsamic glazed lamb chops with couscous']

# %%
name_ingredients_cuisine
